# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from matplotlib.cm import get_cmap
from scipy.stats import truncnorm, qmc
from tqdm import tqdm
import sbibm
from sbibm.tasks.gaussian_linear.task import GaussianLinear
import scipy.stats as stats
from scipy.stats import wasserstein_distance, ks_2samp
import seaborn as sns
from itertools import product
import random
import os
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import hamming_loss
from sklearn.model_selection import train_test_split
import scipy.stats as stats
from scipy.stats import uniform
from matplotlib import colormaps
import matplotlib.colors as mcolors
import ili
from ili.dataloaders import NumpyLoader
from ili.inference import InferenceRunner
from ili.validation.metrics import PosteriorCoverage, PlotSinglePosterior
from torch.distributions import Distribution, Uniform, HalfNormal
from torch.distributions.utils import broadcast_all
import math
from ili.utils.distributions_pt import CustomIndependent
import itertools
import pickle
# Device configuration
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Device:', device)

sns.set(style="whitegrid", context="paper", font_scale=1.2)

# %%
with open('/home/x-ctirapongpra/scratch/toy-2-dim-models/uniform/posterior.pkl', 'rb') as f:
    posterior_ensemble_old = pickle.load(f)
with open('/home/x-ctirapongpra/scratch/toy-2-dim-models/taileduniform/posterior.pkl', 'rb') as f:
    posterior_ensemble = pickle.load(f)

# %%
class TailedNormal(Distribution):
    arg_constraints = {
        'a': torch.distributions.constraints.real,
        'b': torch.distributions.constraints.dependent,
        'sigma': torch.distributions.constraints.positive,
    }
    support = torch.distributions.constraints.real
    has_rsample = False

    def __init__(self, a, b, sigma, validate_args=None):
        self.a, self.b, self.sigma = broadcast_all(a, b, sigma)
        if torch.any(self.a >= self.b):
            raise ValueError("`a` must be less than `b`.")
        
        self.Z = math.sqrt(2 * math.pi) * self.sigma + (self.b - self.a)
        self.A = math.sqrt(2 * math.pi) * self.sigma / self.Z
        self.B = (self.b - self.a) / self.Z

        self.halfnormal = HalfNormal(self.sigma)

        super().__init__(batch_shape=self.a.size(), validate_args=validate_args)

    def log_prob(self, x):
        x, a, b, sigma = broadcast_all(x, self.a, self.b, self.sigma)

        logA = torch.log(self.A.to(dtype=x.dtype, device=x.device))
        logB = torch.log(self.B.to(dtype=x.dtype, device=x.device))
        log_uniform = logB - torch.log(b - a)

        # left: x <= a => z = a - x
        z_left = torch.abs(a - x)
        log_halfnorm_left = self.halfnormal.log_prob(z_left) + logA - math.log(2.0)

        # right: x >= b => z = x - b
        z_right = torch.abs(x - b)
        log_halfnorm_right = self.halfnormal.log_prob(z_right) + logA - math.log(2.0)

        return torch.where(x <= a, log_halfnorm_left,
               torch.where(x >= b, log_halfnorm_right,
               log_uniform))

    def cdf(self, x):
        x, a, b, sigma = broadcast_all(x, self.a, self.b, self.sigma)
        sqrt2 = math.sqrt(2.0)

        def Phi(z):  # Standard Normal CDF
            return 0.5 * (1 + torch.erf(z / sqrt2))

        left_cdf = self.A * Phi((x - a) / sigma)
        center_cdf = 0.5 * self.A + self.B * (x - a) / (b - a)
        right_cdf = self.B + self.A * Phi((x - b) / sigma)

        return torch.where(x <= a, left_cdf,
               torch.where(x >= b, right_cdf,
               center_cdf))
    
    def icdf(self, u):
        # Helper function for the Inverse Standard Normal CDF
        def inv_Phi(p):
            # Clamping p to avoid NaNs from erfinv at the boundaries 0 and 1
            p_clamped = torch.clamp(p, 1e-9, 1.0 - 1e-9)
            return math.sqrt(2.0) * torch.erfinv(2.0 * p_clamped - 1.0)

        # Thresholds dividing the distribution regions
        thresh_left = 0.5 * self.A
        thresh_right = 1.0 - 0.5 * self.A

        u_left_norm = u / self.A
        left_tail = self.a + self.sigma * inv_Phi(u_left_norm)

        u_right_norm = (u - self.B) / self.A
        right_tail = self.b + self.sigma * inv_Phi(u_right_norm)

        u_middle_norm = (u - thresh_left) / self.B
        middle = self.a + u_middle_norm * (self.b - self.a)

        return torch.where(u < thresh_left, left_tail,
                           torch.where(u > thresh_right, right_tail, middle))
        

    def sample(self, sample_shape=torch.Size()):
        u = torch.rand(sample_shape + self.a.shape, device=self.a.device)
        thresh_left = 0.5 * self.A
        thresh_right = 1.0 - 0.5 * self.A

        left_tail = self.a - self.halfnormal.sample(sample_shape)
        right_tail = self.b + self.halfnormal.sample(sample_shape)

        x_middle = self.a + (u - thresh_left) * (self.b - self.a) / self.B

        return torch.where(u < thresh_left, left_tail,
               torch.where(u > thresh_right, right_tail,
               x_middle))
    
    def sample_lhs(self, n_samples):
        """Sample using Latin Hypercube Sampling"""
        # Generate LHS samples in [0,1]^d
        sampler = qmc.LatinHypercube(d=len(self.a.flatten()), seed=42)
        u_samples = sampler.random(n_samples)
        u_tensor = torch.tensor(u_samples, dtype=torch.float32, device=self.a.device)
        
        # Transform using inverse CDF
        return self.icdf(u_tensor)

    def mean(self):
        return 0.5 * (self.a + self.b)

IndependentTailedNormal = type('IndependentTailedNormal', (CustomIndependent,), {'Distribution': TailedNormal})

# %%
def sample_uniform_lhs(n_samples, dim, low=-1.0, high=1.0, device='cpu'):
    """Generate uniform samples using Latin Hypercube Sampling"""
    sampler = qmc.LatinHypercube(d=dim, seed=42)
    u_samples = sampler.random(n_samples)
    # Transform from [0,1]^d to [low,high]^d
    samples = low + (high - low) * u_samples
    return torch.tensor(samples, dtype=torch.float32, device=device)

# %%
class SBIEvaluator:
   def __init__(self, param_names=['θ₁', 'θ₂']):
       self.param_names = param_names
   
   def c2st(self, X1, X2):
       """C2ST score - lower is better (0.5 = identical distributions)"""
       X = np.vstack([X1, X2])
       y = np.concatenate([np.zeros(len(X1)), np.ones(len(X2))])
       X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
       clf = LogisticRegression(max_iter=1000)
       y_pred = clf.fit(X_train, y_train).predict(X_test)
       return hamming_loss(y_test, y_pred)
   
   def tarp_score(self, samples, true_theta):
       """TARP calibration score - lower is better"""
       alpha_levels = np.linspace(0.05, 0.95, 19)
       empirical_coverage = []
       
       for alpha in alpha_levels:
           coverage = all(
               np.percentile(samples[:, j], 100*alpha/2) <= true_theta[j] <= 
               np.percentile(samples[:, j], 100*(1-alpha/2))
               for j in range(len(true_theta))
           )
           empirical_coverage.append(coverage)
       
       expected_coverage = 1 - alpha_levels
       return np.mean(np.abs(expected_coverage - empirical_coverage))
   
   def compare(self, samples_dict, true_theta):
       """Compare multiple methods"""
       results = {}
       methods = list(samples_dict.keys())
       
       for method, samples in samples_dict.items():
           results[method] = {
               'tarp': self.tarp_score(samples, true_theta),
               'mean': np.mean(samples, axis=0),
               'std': np.std(samples, axis=0),
               'c2st_vs_others': {}
           }
       
       # C2ST comparisons
       for i, method1 in enumerate(methods):
           for method2 in methods[i+1:]:
               score = self.c2st(samples_dict[method1], samples_dict[method2])
               results[method1]['c2st_vs_others'][method2] = score
               results[method2]['c2st_vs_others'][method1] = score
       
       return results
   
   def print_results(self, results, true_theta):
       """Print concise comparison"""
       methods = list(results.keys())
       
       print("Method Comparison")
       print("-" * 50)
       
       for method in methods:
           stats = results[method]
           print(f"\n{method}:")
           print(f"  TARP: {stats['tarp']:.4f}")
           for i, param in enumerate(self.param_names):
               print(f"  {param}: Mean={stats['mean'][i]:.3f}, Std={stats['std'][i]:.3f}")
           
           if stats['c2st_vs_others']:
               c2st_str = ", ".join([f"{k}={v:.3f}" for k, v in stats['c2st_vs_others'].items()])
               print(f"  C2ST: {c2st_str}")

# %%
class GridEvaluator:
    def __init__(self, simulator, param_ranges, task):
        self.simulator = simulator
        self.param_ranges = param_ranges
        self.task = task

    def create_test_points(self, n_points_per_dim):
        """Create test points on rectangular grid"""
        x_points = np.linspace(self.param_ranges[0][0], self.param_ranges[0][1], n_points_per_dim)
        y_points = np.linspace(self.param_ranges[1][0], self.param_ranges[1][1], n_points_per_dim)
        
        test_points = []
        for x in x_points:
            for y in y_points:
                test_points.append([x, y])
        
        return np.array(test_points)

    def evaluate_all(self, posterior_dict, test_points, n_samples=n_posterior_samples):
        """Evaluate all posteriors including reference"""
        observations = []
        results = {'test_points': test_points}

        for theta in tqdm(test_points):
            x_obs = self.simulator(torch.tensor(theta, dtype=torch.float32))
            observations.append(x_obs)

        results['observations'] = observations

        ref_samples = []
        for x_obs in tqdm(observations, desc="Reference"):
            ref_post = self.task._get_reference_posterior(observation=x_obs.unsqueeze(0))
            ref_samples.append(ref_post.sample((n_samples,)).cpu().numpy())
        results['Reference'] = ref_samples

        for name, posterior in posterior_dict.items():
            samples = []
            for x_obs in tqdm(observations, desc=name):
                samples.append(posterior.sample((n_samples,), x_obs).cpu().numpy())
            results[name] = samples

        return results

    def c2st(self, X1, X2):
        """C2ST score"""
        from sklearn.model_selection import train_test_split
        from sklearn.linear_model import LogisticRegression
        from sklearn.metrics import hamming_loss

        X = np.vstack([X1, X2])
        y = np.concatenate([np.zeros(len(X1)), np.ones(len(X2))])
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
        return hamming_loss(y_test, LogisticRegression(max_iter=1000).fit(X_train, y_train).predict(X_test))

    def compute_c2st_grid(self, results, n_points_per_dim):
        """Compute C2ST for grid points"""
        methods = ['Uniform_NPE', 'TailedNormal_NPE', 'Reference']
        c2st_grid = {}

        for i, m1 in enumerate(methods):
            for m2 in methods[i+1:]:
                comparison_name = f"{m1}_vs_{m2}"
                c2st_values = []
                
                for idx in range(len(results['test_points'])):
                    c2st_val = self.c2st(results[m1][idx], results[m2][idx])
                    c2st_values.append(c2st_val)
                
                c2st_grid[comparison_name] = np.array(c2st_values).reshape(n_points_per_dim, n_points_per_dim)

        return c2st_grid

    def plot_c2st_grid(self, c2st_grid, n_points_per_dim):
        sns.set(style = "white")
        """Plot C2ST scores as heatmaps"""
        comparisons = list(c2st_grid.keys())
        fig, axes = plt.subplots(len(comparisons), 1, figsize=(10, 8*len(comparisons)))
        if len(comparisons) == 1: axes = [axes]

        for i, comp in enumerate(comparisons):
            im = axes[i].imshow(c2st_grid[comp], cmap='RdYlBu_r', vmin=0.3, vmax=0.6, 
                               extent=[self.param_ranges[0][0], self.param_ranges[0][1], 
                                      self.param_ranges[1][0], self.param_ranges[1][1]], 
                               origin='lower')
            
            # Add text annotations
            for j in range(n_points_per_dim):
                for k in range(n_points_per_dim):
                    value = c2st_grid[comp][j, k]
                    color = 'white' if value > 0.5 else 'black'
                    
                    # Calculate pixel coordinates for centering
                    x_extent = self.param_ranges[0][1] - self.param_ranges[0][0]
                    y_extent = self.param_ranges[1][1] - self.param_ranges[1][0]
                    x_pos = self.param_ranges[0][0] + (k + 0.5) * x_extent / n_points_per_dim
                    y_pos = self.param_ranges[1][0] + (j + 0.5) * y_extent / n_points_per_dim
                    
                    axes[i].text(x_pos, y_pos, f'{value:.2f}', ha='center', va='center', 
                               color=color, fontweight='bold', fontsize=6)
            
            axes[i].set_title(comp.replace('_', ' '), fontsize=16)
            axes[i].set_xlabel('Parameter 1', fontsize=14)
            axes[i].set_ylabel('Parameter 2', fontsize=14)
            fig.colorbar(im, ax=axes[i], fraction=0.046, pad=0.04, label='C2ST Score')

        plt.tight_layout()
        filename = f'toy-2-dim-figures/heatmap.png'
        plt.savefig(filename, bbox_inches='tight')
        print(f"Saved plot: {filename}")
        plt.show()

# %%
n_simulations = 4000
n_posterior_samples = 2000

# Parameters ranges
param_1_range = (-1.0, 1.0)
param_2_range = (-1.0, 1.0)
param_ranges = [param_1_range, param_2_range]

param_1_width = param_1_range[1] - param_1_range[0]
param_2_width = param_2_range[1] - param_2_range[0]

# Scale sigma relative to parameter ranges
sigma_scale = 0.1
sigmas = [sigma_scale * (high - low) for low, high in param_ranges]

# Task setup
task = GaussianLinear(
    dim=2, prior_scale=param_1_width/2
)
simulator = task.get_simulator()

# %%
# Training for edge cases
# Define theta_true close to the lower bounds of each parameter

theta_true_edge = np.array([
    param_1_range[1] - 0.1 * param_1_width,
    param_2_range[1] - 0.1 * param_2_width
])

# Print selected parameter values
print(f"  Param 1: [{param_ranges[0][0]}, {param_ranges[0][1]}] -> selected: {theta_true_edge[0]:.3f}")
print(f"  Param 2: [{param_ranges[1][0]}, {param_ranges[1][1]}] -> selected: {theta_true_edge[1]:.3f}")

# Generate observation using the edge case theta_true
x_obs_edge = simulator(torch.Tensor(theta_true_edge))

# Sample from uniform-trained model
samples_uniform = posterior_ensemble_old.sample((n_posterior_samples,), x_obs_edge)
samples_uniform = samples_uniform.cpu().numpy()

# Sample from TailedNormal-trained model  
samples_tailed = posterior_ensemble.sample((n_posterior_samples,), x_obs_edge)
samples_tailed = samples_tailed.cpu().numpy()

# Get reference posterior for the edge case
xobs_edge = x_obs_edge.clone().detach()
ref_edge = task._get_reference_posterior(observation=xobs_edge)
ref_samples_edge = ref_edge.sample((n_posterior_samples,))
# Out:
#   Param 1: [-1.0, 1.0] -> selected: 0.800
#   Param 2: [-1.0, 1.0] -> selected: 0.800
# Drawing 1336 posterior samples:   0%|          | 0/1336 [00:00<?, ?it/s]
# Drawing 1336 posterior samples: 100%|██████████| 1336/1336 [00:01<00:00, 1078.51it/s]
# Drawing 664 posterior samples: 100%|██████████| 664/664 [00:00<00:00, 1802.06it/s]
# Drawing 1414 posterior samples: 100%|██████████| 1414/1414 [00:00<00:00, 200444.30it/s]
# Drawing 586 posterior samples: 100%|██████████| 586/586 [00:00<00:00, 149659.75it/s]

# %%
# Create evaluator and run comparison
evaluator = SBIEvaluator()

samples_dict = {
   'Uniform_NPE': samples_uniform,
   'TailedNormal_NPE': samples_tailed,
   'RefPosterior': ref_samples_edge.numpy()
}

results = evaluator.compare(samples_dict, theta_true_edge)
evaluator.print_results(results, theta_true_edge)
# Out:
# Method Comparison
# --------------------------------------------------
#
# Uniform_NPE:
#   TARP: 0.3737
#   θ₁: Mean=0.266, Std=0.435
#   θ₂: Mean=0.611, Std=0.255
#   C2ST: TailedNormal_NPE=0.443, RefPosterior=0.447
#
# TailedNormal_NPE:
#   TARP: 0.3158
#   θ₁: Mean=0.337, Std=0.497
#   θ₂: Mean=0.678, Std=0.303
#   C2ST: Uniform_NPE=0.443, RefPosterior=0.480
#
# RefPosterior:
#   TARP: 0.3737
#   θ₁: Mean=0.405, Std=0.300
#   θ₂: Mean=0.665, Std=0.300
#   C2ST: Uniform_NPE=0.447, TailedNormal_NPE=0.480

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 12))

methods = ['Uniform', 'TailedNormal', 'Reference']
samples_list = [samples_uniform, samples_tailed, ref_samples_edge.numpy()]

for i, param in enumerate(['Parameter 1', 'Parameter 2']):
   for method, samples in zip(methods, samples_list):
       axes[i].hist(samples[:, i], bins=np.linspace(-2,2,100), alpha=0.4, density=True, label=method, edgecolor='black')
   
   axes[i].axvline(theta_true_edge[i], color='red', linestyle='--', linewidth=2, label='True θ')
   axes[i].set_title(f'{param}')
   axes[i].legend()

plt.tight_layout()
os.makedirs('toy-2-dim-figures', exist_ok=True)
filename = f'toy-2-dim-figures/histogram.png'
plt.savefig(filename, bbox_inches='tight')
print(f"Saved plot: {filename}")
plt.show()
# Out:
# Saved plot: toy-2-dim-figures/histogram.png

# %%
# Create corner plot
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

methods = ['Uniform', 'TailedNormal', 'Reference']
samples_list = [samples_uniform, samples_tailed, ref_samples_edge.numpy()]
colors = ['blue', 'green', 'orange']
param_names = ['Parameter 1', 'Parameter 2']

# Plot marginal distributions (diagonal)
for i in range(2):
    ax = axes[i, i]
    for method, samples, color in zip(methods, samples_list, colors):
        sns.kdeplot(data=samples[:, i], ax=ax, label=method, color=color, alpha=0.7)
    
    # Add true parameter line
    ax.axvline(theta_true_edge[i], color='red', linestyle='--', linewidth=2, label='True θ')
    ax.set_xlabel(param_names[i])
    ax.set_ylabel('Density')
    if i == 0:
        ax.legend()

# Plot joint distributions (off-diagonal)
ax = axes[1, 0]  # Bottom-left for joint distribution
for method, samples, color in zip(methods, samples_list, colors):
    sns.kdeplot(x=samples[:, 0], y=samples[:, 1], ax=ax, color=color, alpha=0.6, 
                levels=[0.05, 0.32, 1], label=method, fill=False)

# Add true parameter point
ax.scatter(theta_true_edge[0], theta_true_edge[1], color='red', s=100, 
           marker='*', label='True θ', zorder=10)

# Add red lines to show true parameter values as boundaries
ax.axvline(theta_true_edge[0], color='red', linestyle='--', linewidth=2, alpha=0.8)
ax.axhline(theta_true_edge[1], color='red', linestyle='--', linewidth=2, alpha=0.8)

# Add black boundary at prior edge (x=1 and y=1)
ax.axvline(1.0, color='black', linestyle='-', linewidth=2, alpha=1.0, label='Prior boundary')
ax.axhline(1.0, color='black', linestyle='-', linewidth=2, alpha=1.0)

ax.set_xlabel(param_names[0])
ax.set_ylabel(param_names[1])
ax.legend()

# Remove top-right subplot (not needed in corner plot)
axes[0, 1].remove()

plt.tight_layout()
filename = f'toy-2-dim-figures/corner.png'
plt.savefig(filename, bbox_inches='tight')
print(f"Saved plot: {filename}")
plt.show()
# Out:
# Saved plot: toy-2-dim-figures/corner.png

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

methods = ['Uniform', 'TailedNormal', 'Reference']
samples_list = [samples_uniform, samples_tailed, ref_samples_edge.numpy()]

for i, param in enumerate(['Parameter 1', 'Parameter 2']):
   data = [samples[:, i] for samples in samples_list]
   
   axes[i].boxplot(data, labels=methods)
   axes[i].axhline(theta_true_edge[i], color='red', linestyle='--', linewidth=2, label='True θ')
   axes[i].set_title(f'{param}')
   axes[i].legend()

plt.tight_layout()
filename = f'toy-2-dim-figures/boxpot.png'
plt.savefig(filename, bbox_inches='tight')
print(f"Saved plot: {filename}")
plt.show()
# Out:
# /tmp/ipykernel_287678/3898867095.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[i].boxplot(data, labels=methods)
# /tmp/ipykernel_287678/3898867095.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[i].boxplot(data, labels=methods)
# Saved plot: toy-2-dim-figures/boxpot.png

# %%
n_points_per_dim = 20
rect_evaluator = GridEvaluator(simulator, param_ranges, task)

posterior_dict = {
    'Uniform_NPE': posterior_ensemble_old,
    'TailedNormal_NPE': posterior_ensemble
}

test_points = rect_evaluator.create_test_points(n_points_per_dim)
results = rect_evaluator.evaluate_all(posterior_dict, test_points)
c2st_grid = rect_evaluator.compute_c2st_grid(results, n_points_per_dim)
# Out:
# 100%|██████████| 400/400 [00:00<00:00, 2568.31it/s]
# Reference: 100%|██████████| 400/400 [00:00<00:00, 4341.87it/s]
# Drawing 1373 posterior samples: 100%|██████████| 1373/1373 [00:00<00:00, 104962.72it/s]
# Drawing 627 posterior samples: 100%|██████████| 627/627 [00:00<00:00, 139602.33it/s]
# Drawing 1343 posterior samples: 100%|██████████| 1343/1343 [00:00<00:00, 191629.54it/s]
# Drawing 657 posterior samples: 100%|██████████| 657/657 [00:00<00:00, 174199.24it/s]
# Drawing 1350 posterior samples: 100%|██████████| 1350/1350 [00:00<00:00, 127515.15it/s]
# Drawing 650 posterior samples: 100%|██████████| 650/650 [00:00<00:00, 171702.83it/s]
# Drawing 1347 posterior samples: 100%|██████████| 1347/1347 [00:00<00:00, 201122.33it/s]
# Drawing 653 posterior samples: 100%|██████████| 653/653 [00:00<00:00, 47559.09it/s]
# Drawing 1368 posterior samples: 100%|██████████| 1368/1368 [00:00<00:00, 207914.19it/s]
# Drawing 632 posterior samples: 100%|██████████| 632/632 [00:00<00:00, 166444.82it/s]
# Drawing 1342 posterior samples: 100%|██████████| 1342/1342 [00:00<00:00, 35904.32it/s]
# Drawing 658 posterior samples: 100%|██████████| 658/658 [00:00<00:00, 154035.39it/s]
# Drawing 1363 posterior samples: 100%|██████████| 1363/1363 [00:00<00:00, 202667.20it/s]
# Drawing 637 posterior samples: 100%|██████████| 637/637 [00:00<00:00, 171608.43it/s]
# Drawing 1353 posterior samples: 100%|██████████| 1353/1353 [00:00<00:00, 202162.14it/s]
# Drawing 647 posterior samples: 100%|██████████| 647/647 [00:00<00:00, 172969.26it/s]
# Drawing 1351 posterior samples: 100%|██████████| 1351/1351 [00:00<00:00, 199160.15it/s]
# Drawing 649 posterior samples: 100%|██████████| 649/649 [00:00<00:00, 173360.29it/s]
# Drawing 1315 posterior samples: 100%|██████████| 1315/1315 [00:00<00:00, 197024.71it/s]
# Drawing 685 posterior samples: 100%|██████████| 685/685 [00:00<00:00, 162175.34it/s]
# Drawing 1346 posterior samples: 100%|██████████| 1346/1346 [00:00<00:00, 167215.60it/s]
# Drawing 654 posterior samples: 100%|██████████| 654/654 [00:00<00:00, 172076.71it/s]
# Drawing 1341 posterior samples: 100%|██████████| 1341/1341 [00:00<00:00, 199955.98it/s]
# Drawing 659 posterior samples: 100%|██████████| 659/659 [00:00<00:00, 172461.87it/s]
# Drawing 1327 posterior samples: 100%|██████████| 1327/1327 [00:00<00:00, 153075.95it/s]
# Drawing 673 posterior samples: 100%|██████████| 673/673 [00:00<00:00, 172963.64it/s]
# Drawing 1316 posterior samples: 100%|██████████| 1316/1316 [00:00<00:00, 192223.72it/s]
# Drawing 684 posterior samples: 100%|██████████| 684/684 [00:00<00:00, 176385.12it/s]
# Drawing 1369 posterior samples: 100%|██████████| 1369/1369 [00:00<00:00, 173668.52it/s]
# Drawing 631 posterior samples: 100%|██████████| 631/631 [00:00<00:00, 144040.81it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:00<00:00, 194528.93it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 175645.36it/s]
# Drawing 1358 posterior samples: 100%|██████████| 1358/1358 [00:00<00:00, 202865.86it/s]
# Drawing 642 posterior samples: 100%|██████████| 642/642 [00:00<00:00, 163196.56it/s]
# Drawing 1321 posterior samples: 100%|██████████| 1321/1321 [00:00<00:00, 167215.20it/s]
# Drawing 679 posterior samples: 100%|██████████| 679/679 [00:00<00:00, 176978.15it/s]
# Drawing 1369 posterior samples: 100%|██████████| 1369/1369 [00:00<00:00, 99989.59it/s]
# Drawing 631 posterior samples: 100%|██████████| 631/631 [00:00<00:00, 166767.85it/s]
# Drawing 1341 posterior samples: 100%|██████████| 1341/1341 [00:00<00:00, 199594.10it/s]
# Drawing 659 posterior samples: 100%|██████████| 659/659 [00:00<00:00, 172709.72it/s]
# Drawing 1335 posterior samples: 100%|██████████| 1335/1335 [00:00<00:00, 194883.61it/s]
# Drawing 665 posterior samples: 100%|██████████| 665/665 [00:00<00:00, 151029.47it/s]
# Drawing 1334 posterior samples: 100%|██████████| 1334/1334 [00:00<00:00, 198912.21it/s]
# Drawing 666 posterior samples: 100%|██████████| 666/666 [00:00<00:00, 175201.11it/s]
# Drawing 1375 posterior samples: 100%|██████████| 1375/1375 [00:00<00:00, 150578.80it/s]
# Drawing 625 posterior samples: 100%|██████████| 625/625 [00:00<00:00, 170378.27it/s]
# Drawing 1336 posterior samples: 100%|██████████| 1336/1336 [00:00<00:00, 198181.79it/s]
# Drawing 664 posterior samples: 100%|██████████| 664/664 [00:00<00:00, 176624.67it/s]
# Drawing 1337 posterior samples: 100%|██████████| 1337/1337 [00:00<00:00, 203978.77it/s]
# Drawing 663 posterior samples: 100%|██████████| 663/663 [00:00<00:00, 173357.24it/s]
# Drawing 1329 posterior samples: 100%|██████████| 1329/1329 [00:00<00:00, 204049.71it/s]
# Drawing 671 posterior samples: 100%|██████████| 671/671 [00:00<00:00, 172185.87it/s]
# Drawing 1354 posterior samples: 100%|██████████| 1354/1354 [00:00<00:00, 182185.54it/s]
# Drawing 646 posterior samples: 100%|██████████| 646/646 [00:00<00:00, 169535.75it/s]
# Drawing 1358 posterior samples: 100%|██████████| 1358/1358 [00:00<00:00, 206904.17it/s]
# Drawing 642 posterior samples: 100%|██████████| 642/642 [00:00<00:00, 165361.29it/s]
# Drawing 1350 posterior samples: 100%|██████████| 1350/1350 [00:00<00:00, 199855.65it/s]
# Drawing 650 posterior samples: 100%|██████████| 650/650 [00:00<00:00, 116893.09it/s]
# Drawing 1379 posterior samples: 100%|██████████| 1379/1379 [00:00<00:00, 139227.91it/s]
# Drawing 621 posterior samples: 100%|██████████| 621/621 [00:00<00:00, 166198.49it/s]
# Drawing 1347 posterior samples: 100%|██████████| 1347/1347 [00:00<00:00, 205976.43it/s]
# Drawing 653 posterior samples: 100%|██████████| 653/653 [00:00<00:00, 118952.47it/s]
# Drawing 1377 posterior samples: 100%|██████████| 1377/1377 [00:00<00:00, 200456.64it/s]
# Drawing 623 posterior samples: 100%|██████████| 623/623 [00:00<00:00, 164322.19it/s]
# Drawing 1349 posterior samples: 100%|██████████| 1349/1349 [00:00<00:00, 163818.18it/s]
# Drawing 651 posterior samples: 100%|██████████| 651/651 [00:00<00:00, 167412.13it/s]
# Drawing 1353 posterior samples: 100%|██████████| 1353/1353 [00:00<00:00, 158862.70it/s]
# Drawing 647 posterior samples: 100%|██████████| 647/647 [00:00<00:00, 168302.82it/s]
# Drawing 1360 posterior samples: 100%|██████████| 1360/1360 [00:00<00:00, 200670.28it/s]
# Drawing 640 posterior samples: 100%|██████████| 640/640 [00:00<00:00, 171217.92it/s]
# Drawing 1339 posterior samples: 100%|██████████| 1339/1339 [00:00<00:00, 178149.82it/s]
# Drawing 661 posterior samples: 100%|██████████| 661/661 [00:00<00:00, 171487.29it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:00<00:00, 196411.77it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 170130.61it/s]
# Drawing 1322 posterior samples: 100%|██████████| 1322/1322 [00:00<00:00, 193659.89it/s]
# Drawing 678 posterior samples: 100%|██████████| 678/678 [00:00<00:00, 99962.67it/s]
# Drawing 1352 posterior samples: 100%|██████████| 1352/1352 [00:00<00:00, 198296.99it/s]
# Drawing 648 posterior samples: 100%|██████████| 648/648 [00:00<00:00, 163976.41it/s]
# Drawing 1356 posterior samples: 100%|██████████| 1356/1356 [00:00<00:00, 198841.95it/s]
# Drawing 644 posterior samples: 100%|██████████| 644/644 [00:00<00:00, 166994.24it/s]
# Drawing 1316 posterior samples: 100%|██████████| 1316/1316 [00:00<00:00, 196060.95it/s]
# Drawing 684 posterior samples: 100%|██████████| 684/684 [00:00<00:00, 174316.68it/s]
# Drawing 1333 posterior samples: 100%|██████████| 1333/1333 [00:00<00:00, 196175.69it/s]
# Drawing 667 posterior samples: 100%|██████████| 667/667 [00:00<00:00, 178634.87it/s]
# Drawing 1326 posterior samples: 100%|██████████| 1326/1326 [00:00<00:00, 191240.19it/s]
# Drawing 674 posterior samples: 100%|██████████| 674/674 [00:00<00:00, 177684.53it/s]
# Drawing 1331 posterior samples: 100%|██████████| 1331/1331 [00:00<00:00, 190747.89it/s]
# Drawing 669 posterior samples: 100%|██████████| 669/669 [00:00<00:00, 175935.13it/s]
# Drawing 1383 posterior samples: 100%|██████████| 1383/1383 [00:00<00:00, 194244.46it/s]
# Drawing 617 posterior samples: 100%|██████████| 617/617 [00:00<00:00, 165794.45it/s]
# Drawing 1396 posterior samples: 100%|██████████| 1396/1396 [00:00<00:00, 198429.18it/s]
# Drawing 604 posterior samples: 100%|██████████| 604/604 [00:00<00:00, 160177.01it/s]
# Drawing 1310 posterior samples: 100%|██████████| 1310/1310 [00:00<00:00, 188291.64it/s]
# Drawing 690 posterior samples: 100%|██████████| 690/690 [00:00<00:00, 174709.92it/s]
# Drawing 1343 posterior samples: 100%|██████████| 1343/1343 [00:00<00:00, 105338.01it/s]
# Drawing 657 posterior samples: 100%|██████████| 657/657 [00:00<00:00, 128062.91it/s]
# Drawing 1342 posterior samples: 100%|██████████| 1342/1342 [00:00<00:00, 169255.35it/s]
# Drawing 658 posterior samples: 100%|██████████| 658/658 [00:00<00:00, 155283.41it/s]
# Drawing 1348 posterior samples: 100%|██████████| 1348/1348 [00:00<00:00, 195935.74it/s]
# Drawing 652 posterior samples: 100%|██████████| 652/652 [00:00<00:00, 121655.15it/s]
# Drawing 1344 posterior samples: 100%|██████████| 1344/1344 [00:00<00:00, 195171.71it/s]
# Drawing 656 posterior samples: 100%|██████████| 656/656 [00:00<00:00, 138508.10it/s]
# Drawing 1313 posterior samples: 100%|██████████| 1313/1313 [00:00<00:00, 192523.03it/s]
# Drawing 687 posterior samples: 100%|██████████| 687/687 [00:00<00:00, 138008.85it/s]
# Drawing 1319 posterior samples: 100%|██████████| 1319/1319 [00:00<00:00, 192843.24it/s]
# Drawing 681 posterior samples: 100%|██████████| 681/681 [00:00<00:00, 179349.56it/s]
# Drawing 1384 posterior samples: 100%|██████████| 1384/1384 [00:00<00:00, 197224.77it/s]
# Drawing 616 posterior samples: 100%|██████████| 616/616 [00:00<00:00, 164660.71it/s]
# Drawing 1329 posterior samples: 100%|██████████| 1329/1329 [00:00<00:00, 193368.37it/s]
# Drawing 671 posterior samples: 100%|██████████| 671/671 [00:00<00:00, 172386.25it/s]
# Drawing 1346 posterior samples: 100%|██████████| 1346/1346 [00:00<00:00, 164276.70it/s]
# Drawing 654 posterior samples: 100%|██████████| 654/654 [00:00<00:00, 168721.54it/s]
# Drawing 1328 posterior samples: 100%|██████████| 1328/1328 [00:00<00:00, 193102.30it/s]
# Drawing 672 posterior samples: 100%|██████████| 672/672 [00:00<00:00, 172569.17it/s]
# Drawing 1318 posterior samples: 100%|██████████| 1318/1318 [00:00<00:00, 192355.08it/s]
# Drawing 682 posterior samples: 100%|██████████| 682/682 [00:00<00:00, 174538.74it/s]
# Drawing 1343 posterior samples: 100%|██████████| 1343/1343 [00:00<00:00, 196454.86it/s]
# Drawing 657 posterior samples: 100%|██████████| 657/657 [00:00<00:00, 176238.02it/s]
# Drawing 1319 posterior samples: 100%|██████████| 1319/1319 [00:00<00:00, 192527.82it/s]
# Drawing 681 posterior samples: 100%|██████████| 681/681 [00:00<00:00, 178308.32it/s]
# Drawing 1310 posterior samples: 100%|██████████| 1310/1310 [00:00<00:00, 190135.59it/s]
# Drawing 690 posterior samples: 100%|██████████| 690/690 [00:00<00:00, 10825.91it/s]
# Drawing 1307 posterior samples: 100%|██████████| 1307/1307 [00:00<00:00, 179459.70it/s]
# Drawing 693 posterior samples: 100%|██████████| 693/693 [00:00<00:00, 167810.90it/s]
# Drawing 1347 posterior samples: 100%|██████████| 1347/1347 [00:00<00:00, 188387.05it/s]
# Drawing 653 posterior samples: 100%|██████████| 653/653 [00:00<00:00, 170731.86it/s]
# Drawing 1374 posterior samples: 100%|██████████| 1374/1374 [00:00<00:00, 198572.59it/s]
# Drawing 626 posterior samples: 100%|██████████| 626/626 [00:00<00:00, 164081.63it/s]
# Drawing 1328 posterior samples: 100%|██████████| 1328/1328 [00:00<00:00, 169451.36it/s]
# Drawing 672 posterior samples: 100%|██████████| 672/672 [00:00<00:00, 175317.05it/s]
# Drawing 1343 posterior samples: 100%|██████████| 1343/1343 [00:00<00:00, 197446.47it/s]
# Drawing 657 posterior samples: 100%|██████████| 657/657 [00:00<00:00, 175051.31it/s]
# Drawing 1351 posterior samples: 100%|██████████| 1351/1351 [00:00<00:00, 198720.14it/s]
# Drawing 649 posterior samples: 100%|██████████| 649/649 [00:00<00:00, 170184.64it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:00<00:00, 192872.88it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 170637.83it/s]
# Drawing 1363 posterior samples: 100%|██████████| 1363/1363 [00:00<00:00, 191602.25it/s]
# Drawing 637 posterior samples: 100%|██████████| 637/637 [00:00<00:00, 168885.69it/s]
# Drawing 1305 posterior samples: 100%|██████████| 1305/1305 [00:00<00:00, 189836.88it/s]
# Drawing 695 posterior samples: 100%|██████████| 695/695 [00:00<00:00, 178399.10it/s]
# Drawing 1340 posterior samples: 100%|██████████| 1340/1340 [00:00<00:00, 193305.84it/s]
# Drawing 660 posterior samples: 100%|██████████| 660/660 [00:00<00:00, 174015.63it/s]
# Drawing 1352 posterior samples: 100%|██████████| 1352/1352 [00:00<00:00, 197056.64it/s]
# Drawing 648 posterior samples: 100%|██████████| 648/648 [00:00<00:00, 168291.58it/s]
# Drawing 1336 posterior samples: 100%|██████████| 1336/1336 [00:00<00:00, 184371.08it/s]
# Drawing 664 posterior samples: 100%|██████████| 664/664 [00:00<00:00, 171017.37it/s]
# Drawing 1325 posterior samples: 100%|██████████| 1325/1325 [00:00<00:00, 188599.21it/s]
# Drawing 675 posterior samples: 100%|██████████| 675/675 [00:00<00:00, 174504.14it/s]
# Drawing 1331 posterior samples: 100%|██████████| 1331/1331 [00:00<00:00, 187380.21it/s]
# Drawing 669 posterior samples: 100%|██████████| 669/669 [00:00<00:00, 172761.32it/s]
# Drawing 1346 posterior samples: 100%|██████████| 1346/1346 [00:00<00:00, 190908.06it/s]
# Drawing 654 posterior samples: 100%|██████████| 654/654 [00:00<00:00, 167270.86it/s]
# Drawing 1356 posterior samples: 100%|██████████| 1356/1356 [00:00<00:00, 195613.97it/s]
# Drawing 644 posterior samples: 100%|██████████| 644/644 [00:00<00:00, 170042.92it/s]
# Drawing 1349 posterior samples: 100%|██████████| 1349/1349 [00:00<00:00, 193910.56it/s]
# Drawing 651 posterior samples: 100%|██████████| 651/651 [00:00<00:00, 170773.15it/s]
# Drawing 1346 posterior samples: 100%|██████████| 1346/1346 [00:00<00:00, 196873.11it/s]
# Drawing 654 posterior samples: 100%|██████████| 654/654 [00:00<00:00, 170546.81it/s]
# Drawing 1362 posterior samples: 100%|██████████| 1362/1362 [00:00<00:00, 199255.04it/s]
# Drawing 638 posterior samples: 100%|██████████| 638/638 [00:00<00:00, 164401.67it/s]
# Drawing 1335 posterior samples: 100%|██████████| 1335/1335 [00:00<00:00, 183274.28it/s]
# Drawing 665 posterior samples: 100%|██████████| 665/665 [00:00<00:00, 172589.08it/s]
# Drawing 1325 posterior samples: 100%|██████████| 1325/1325 [00:00<00:00, 190343.28it/s]
# Drawing 675 posterior samples: 100%|██████████| 675/675 [00:00<00:00, 174128.49it/s]
# Drawing 1357 posterior samples: 100%|██████████| 1357/1357 [00:00<00:00, 196950.43it/s]
# Drawing 643 posterior samples: 100%|██████████| 643/643 [00:00<00:00, 168400.72it/s]
# Drawing 1366 posterior samples: 100%|██████████| 1366/1366 [00:00<00:00, 199339.62it/s]
# Drawing 634 posterior samples: 100%|██████████| 634/634 [00:00<00:00, 162810.80it/s]
# Drawing 1366 posterior samples: 100%|██████████| 1366/1366 [00:00<00:00, 191811.83it/s]
# Drawing 634 posterior samples: 100%|██████████| 634/634 [00:00<00:00, 165898.60it/s]
# Drawing 1304 posterior samples: 100%|██████████| 1304/1304 [00:00<00:00, 186039.40it/s]
# Drawing 696 posterior samples: 100%|██████████| 696/696 [00:00<00:00, 38421.11it/s]
# Drawing 1334 posterior samples: 100%|██████████| 1334/1334 [00:00<00:00, 194169.96it/s]
# Drawing 666 posterior samples: 100%|██████████| 666/666 [00:00<00:00, 104488.91it/s]
# Drawing 1365 posterior samples: 100%|██████████| 1365/1365 [00:00<00:00, 197865.04it/s]
# Drawing 635 posterior samples: 100%|██████████| 635/635 [00:00<00:00, 140763.33it/s]
# Drawing 1342 posterior samples: 100%|██████████| 1342/1342 [00:00<00:00, 194436.97it/s]
# Drawing 658 posterior samples: 100%|██████████| 658/658 [00:00<00:00, 136349.59it/s]
# Drawing 1359 posterior samples: 100%|██████████| 1359/1359 [00:00<00:00, 163818.34it/s]
# Drawing 641 posterior samples: 100%|██████████| 641/641 [00:00<00:00, 171463.58it/s]
# Drawing 1358 posterior samples: 100%|██████████| 1358/1358 [00:00<00:00, 156256.58it/s]
# Drawing 642 posterior samples: 100%|██████████| 642/642 [00:00<00:00, 170308.21it/s]
# Drawing 1335 posterior samples: 100%|██████████| 1335/1335 [00:00<00:00, 168656.50it/s]
# Drawing 665 posterior samples: 100%|██████████| 665/665 [00:00<00:00, 177081.59it/s]
# Drawing 1342 posterior samples: 100%|██████████| 1342/1342 [00:00<00:00, 193707.62it/s]
# Drawing 658 posterior samples: 100%|██████████| 658/658 [00:00<00:00, 112545.96it/s]
# Drawing 1364 posterior samples: 100%|██████████| 1364/1364 [00:00<00:00, 197358.58it/s]
# Drawing 636 posterior samples: 100%|██████████| 636/636 [00:00<00:00, 164411.55it/s]
# Drawing 1370 posterior samples: 100%|██████████| 1370/1370 [00:00<00:00, 200048.62it/s]
# Drawing 630 posterior samples: 100%|██████████| 630/630 [00:00<00:00, 164903.36it/s]
# Drawing 1335 posterior samples: 100%|██████████| 1335/1335 [00:00<00:00, 195851.55it/s]
# Drawing 665 posterior samples: 100%|██████████| 665/665 [00:00<00:00, 175587.80it/s]
# Drawing 1322 posterior samples: 100%|██████████| 1322/1322 [00:00<00:00, 124584.22it/s]
# Drawing 678 posterior samples: 100%|██████████| 678/678 [00:00<00:00, 2782.20it/s]
# Drawing 1356 posterior samples: 100%|██████████| 1356/1356 [00:00<00:00, 199581.58it/s]
# Drawing 644 posterior samples: 100%|██████████| 644/644 [00:00<00:00, 167180.28it/s]
# Drawing 1325 posterior samples: 100%|██████████| 1325/1325 [00:00<00:00, 198388.35it/s]
# Drawing 675 posterior samples: 100%|██████████| 675/675 [00:00<00:00, 179539.30it/s]
# Drawing 1381 posterior samples: 100%|██████████| 1381/1381 [00:00<00:00, 123685.89it/s]
# Drawing 619 posterior samples: 100%|██████████| 619/619 [00:00<00:00, 167924.08it/s]
# Drawing 1337 posterior samples: 100%|██████████| 1337/1337 [00:00<00:00, 198942.26it/s]
# Drawing 663 posterior samples: 100%|██████████| 663/663 [00:00<00:00, 174609.04it/s]
# Drawing 1340 posterior samples: 100%|██████████| 1340/1340 [00:00<00:00, 189333.58it/s]
# Drawing 660 posterior samples: 100%|██████████| 660/660 [00:00<00:00, 175627.50it/s]
# Drawing 1363 posterior samples: 100%|██████████| 1363/1363 [00:00<00:00, 201049.28it/s]
# Drawing 637 posterior samples: 100%|██████████| 637/637 [00:00<00:00, 169378.20it/s]
# Drawing 1353 posterior samples: 100%|██████████| 1353/1353 [00:00<00:00, 198214.93it/s]
# Drawing 647 posterior samples: 100%|██████████| 647/647 [00:00<00:00, 173156.88it/s]
# Drawing 1357 posterior samples: 100%|██████████| 1357/1357 [00:00<00:00, 198939.90it/s]
# Drawing 643 posterior samples: 100%|██████████| 643/643 [00:00<00:00, 171735.70it/s]
# Drawing 1336 posterior samples: 100%|██████████| 1336/1336 [00:00<00:00, 119352.29it/s]
# Drawing 664 posterior samples: 100%|██████████| 664/664 [00:00<00:00, 169797.45it/s]
# Drawing 1342 posterior samples: 100%|██████████| 1342/1342 [00:00<00:00, 179408.30it/s]
# Drawing 658 posterior samples: 100%|██████████| 658/658 [00:00<00:00, 173248.72it/s]
# Drawing 1358 posterior samples: 100%|██████████| 1358/1358 [00:00<00:00, 201302.87it/s]
# Drawing 642 posterior samples: 100%|██████████| 642/642 [00:00<00:00, 169675.06it/s]
# Drawing 1356 posterior samples: 100%|██████████| 1356/1356 [00:00<00:00, 198626.68it/s]
# Drawing 644 posterior samples: 100%|██████████| 644/644 [00:00<00:00, 170429.16it/s]
# Drawing 1331 posterior samples: 100%|██████████| 1331/1331 [00:00<00:00, 71944.67it/s]
# Drawing 669 posterior samples: 100%|██████████| 669/669 [00:00<00:00, 169086.43it/s]
# Drawing 1359 posterior samples: 100%|██████████| 1359/1359 [00:00<00:00, 195797.58it/s]
# Drawing 641 posterior samples: 100%|██████████| 641/641 [00:00<00:00, 163387.96it/s]
# Drawing 1351 posterior samples: 100%|██████████| 1351/1351 [00:00<00:00, 194698.48it/s]
# Drawing 649 posterior samples: 100%|██████████| 649/649 [00:00<00:00, 170836.16it/s]
# Drawing 1314 posterior samples: 100%|██████████| 1314/1314 [00:00<00:00, 189626.87it/s]
# Drawing 686 posterior samples: 100%|██████████| 686/686 [00:00<00:00, 175476.77it/s]
# Drawing 1394 posterior samples: 100%|██████████| 1394/1394 [00:00<00:00, 197843.19it/s]
# Drawing 606 posterior samples: 100%|██████████| 606/606 [00:00<00:00, 163257.00it/s]
# Drawing 1341 posterior samples: 100%|██████████| 1341/1341 [00:00<00:00, 18028.19it/s]
# Drawing 659 posterior samples: 100%|██████████| 659/659 [00:00<00:00, 168006.71it/s]
# Drawing 1342 posterior samples: 100%|██████████| 1342/1342 [00:00<00:00, 191695.53it/s]
# Drawing 658 posterior samples: 100%|██████████| 658/658 [00:00<00:00, 167507.41it/s]
# Drawing 1362 posterior samples: 100%|██████████| 1362/1362 [00:00<00:00, 192267.17it/s]
# Drawing 638 posterior samples: 100%|██████████| 638/638 [00:00<00:00, 160448.85it/s]
# Drawing 1354 posterior samples: 100%|██████████| 1354/1354 [00:00<00:00, 185548.65it/s]
# Drawing 646 posterior samples: 100%|██████████| 646/646 [00:00<00:00, 169663.14it/s]
# Drawing 1319 posterior samples: 100%|██████████| 1319/1319 [00:00<00:00, 189325.72it/s]
# Drawing 681 posterior samples: 100%|██████████| 681/681 [00:00<00:00, 165564.63it/s]
# Drawing 1392 posterior samples: 100%|██████████| 1392/1392 [00:00<00:00, 153152.28it/s]
# Drawing 608 posterior samples: 100%|██████████| 608/608 [00:00<00:00, 160164.35it/s]
# Drawing 1320 posterior samples: 100%|██████████| 1320/1320 [00:00<00:00, 124359.42it/s]
# Drawing 680 posterior samples: 100%|██████████| 680/680 [00:00<00:00, 174977.10it/s]
# Drawing 1361 posterior samples: 100%|██████████| 1361/1361 [00:00<00:00, 112267.15it/s]
# Drawing 639 posterior samples: 100%|██████████| 639/639 [00:00<00:00, 168669.62it/s]
# Drawing 1359 posterior samples: 100%|██████████| 1359/1359 [00:00<00:00, 201557.96it/s]
# Drawing 641 posterior samples: 100%|██████████| 641/641 [00:00<00:00, 172641.68it/s]
# Drawing 1346 posterior samples: 100%|██████████| 1346/1346 [00:00<00:00, 199165.07it/s]
# Drawing 654 posterior samples: 100%|██████████| 654/654 [00:00<00:00, 172748.59it/s]
# Drawing 1365 posterior samples: 100%|██████████| 1365/1365 [00:00<00:00, 10574.66it/s]
# Drawing 635 posterior samples: 100%|██████████| 635/635 [00:00<00:00, 159083.92it/s]
# Drawing 1361 posterior samples: 100%|██████████| 1361/1361 [00:00<00:00, 175531.13it/s]
# Drawing 639 posterior samples: 100%|██████████| 639/639 [00:00<00:00, 152759.21it/s]
# Drawing 1355 posterior samples: 100%|██████████| 1355/1355 [00:00<00:00, 192262.58it/s]
# Drawing 645 posterior samples: 100%|██████████| 645/645 [00:00<00:00, 171440.18it/s]
# Drawing 1348 posterior samples: 100%|██████████| 1348/1348 [00:00<00:00, 194192.75it/s]
# Drawing 652 posterior samples: 100%|██████████| 652/652 [00:00<00:00, 172807.98it/s]
# Drawing 1333 posterior samples: 100%|██████████| 1333/1333 [00:00<00:00, 193159.69it/s]
# Drawing 667 posterior samples: 100%|██████████| 667/667 [00:00<00:00, 174120.92it/s]
# Drawing 1320 posterior samples: 100%|██████████| 1320/1320 [00:00<00:00, 192198.89it/s]
# Drawing 680 posterior samples: 100%|██████████| 680/680 [00:00<00:00, 179797.44it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:00<00:00, 195961.47it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 173701.89it/s]
# Drawing 1329 posterior samples: 100%|██████████| 1329/1329 [00:00<00:00, 196393.26it/s]
# Drawing 671 posterior samples: 100%|██████████| 671/671 [00:00<00:00, 160977.98it/s]
# Drawing 1333 posterior samples: 100%|██████████| 1333/1333 [00:00<00:00, 24466.16it/s]
# Drawing 667 posterior samples: 100%|██████████| 667/667 [00:00<00:00, 177987.07it/s]
# Drawing 1332 posterior samples: 100%|██████████| 1332/1332 [00:00<00:00, 177426.73it/s]
# Drawing 668 posterior samples: 100%|██████████| 668/668 [00:00<00:00, 176491.03it/s]
# Drawing 1351 posterior samples: 100%|██████████| 1351/1351 [00:00<00:00, 22346.99it/s]
# Drawing 649 posterior samples: 100%|██████████| 649/649 [00:00<00:00, 7705.47it/s]
# Drawing 1335 posterior samples: 100%|██████████| 1335/1335 [00:00<00:00, 197942.44it/s]
# Drawing 665 posterior samples: 100%|██████████| 665/665 [00:00<00:00, 175003.90it/s]
# Drawing 1351 posterior samples: 100%|██████████| 1351/1351 [00:00<00:00, 194745.32it/s]
# Drawing 649 posterior samples: 100%|██████████| 649/649 [00:00<00:00, 174058.65it/s]
# Drawing 1344 posterior samples: 100%|██████████| 1344/1344 [00:00<00:00, 193271.32it/s]
# Drawing 656 posterior samples: 100%|██████████| 656/656 [00:00<00:00, 175085.17it/s]
# Drawing 1339 posterior samples: 100%|██████████| 1339/1339 [00:00<00:00, 189575.46it/s]
# Drawing 661 posterior samples: 100%|██████████| 661/661 [00:00<00:00, 175882.44it/s]
# Drawing 1377 posterior samples: 100%|██████████| 1377/1377 [00:00<00:00, 175607.55it/s]
# Drawing 623 posterior samples: 100%|██████████| 623/623 [00:00<00:00, 170109.46it/s]
# Drawing 1355 posterior samples: 100%|██████████| 1355/1355 [00:00<00:00, 202952.61it/s]
# Drawing 645 posterior samples: 100%|██████████| 645/645 [00:00<00:00, 98336.16it/s]
# Drawing 1337 posterior samples: 100%|██████████| 1337/1337 [00:00<00:00, 92030.47it/s]
# Drawing 663 posterior samples: 100%|██████████| 663/663 [00:00<00:00, 110328.25it/s]
# Drawing 1340 posterior samples: 100%|██████████| 1340/1340 [00:00<00:00, 145911.56it/s]
# Drawing 660 posterior samples: 100%|██████████| 660/660 [00:00<00:00, 176332.29it/s]
# Drawing 1343 posterior samples: 100%|██████████| 1343/1343 [00:00<00:00, 198196.77it/s]
# Drawing 657 posterior samples: 100%|██████████| 657/657 [00:00<00:00, 175922.99it/s]
# Drawing 1364 posterior samples: 100%|██████████| 1364/1364 [00:00<00:00, 203624.38it/s]
# Drawing 636 posterior samples: 100%|██████████| 636/636 [00:00<00:00, 100492.65it/s]
# Drawing 1342 posterior samples: 100%|██████████| 1342/1342 [00:00<00:00, 199537.59it/s]
# Drawing 658 posterior samples: 100%|██████████| 658/658 [00:00<00:00, 172944.73it/s]
# Drawing 1338 posterior samples: 100%|██████████| 1338/1338 [00:00<00:00, 180275.58it/s]
# Drawing 662 posterior samples: 100%|██████████| 662/662 [00:00<00:00, 169544.44it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:00<00:00, 197997.29it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 169291.91it/s]
# Drawing 1357 posterior samples: 100%|██████████| 1357/1357 [00:00<00:00, 178165.36it/s]
# Drawing 643 posterior samples: 100%|██████████| 643/643 [00:00<00:00, 172847.37it/s]
# Drawing 1364 posterior samples: 100%|██████████| 1364/1364 [00:00<00:00, 124000.92it/s]
# Drawing 636 posterior samples: 100%|██████████| 636/636 [00:00<00:00, 1920.47it/s]
# Drawing 1352 posterior samples: 100%|██████████| 1352/1352 [00:01<00:00, 1091.15it/s]
# Drawing 648 posterior samples: 100%|██████████| 648/648 [00:00<00:00, 1142.21it/s]
# Drawing 1359 posterior samples: 100%|██████████| 1359/1359 [00:01<00:00, 1101.46it/s]
# Drawing 641 posterior samples: 100%|██████████| 641/641 [00:00<00:00, 1129.74it/s]
# Drawing 1354 posterior samples: 100%|██████████| 1354/1354 [00:00<00:00, 19330.10it/s]
# Drawing 646 posterior samples: 100%|██████████| 646/646 [00:00<00:00, 160070.92it/s]
# Drawing 1340 posterior samples: 100%|██████████| 1340/1340 [00:00<00:00, 184564.80it/s]
# Drawing 660 posterior samples: 100%|██████████| 660/660 [00:00<00:00, 177816.07it/s]
# Drawing 1336 posterior samples: 100%|██████████| 1336/1336 [00:00<00:00, 199295.45it/s]
# Drawing 664 posterior samples: 100%|██████████| 664/664 [00:00<00:00, 176535.11it/s]
# Drawing 1336 posterior samples: 100%|██████████| 1336/1336 [00:00<00:00, 201394.13it/s]
# Drawing 664 posterior samples: 100%|██████████| 664/664 [00:00<00:00, 178824.83it/s]
# Drawing 1317 posterior samples: 100%|██████████| 1317/1317 [00:00<00:00, 195834.31it/s]
# Drawing 683 posterior samples: 100%|██████████| 683/683 [00:00<00:00, 181563.55it/s]
# Drawing 1353 posterior samples: 100%|██████████| 1353/1353 [00:00<00:00, 208161.30it/s]
# Drawing 647 posterior samples: 100%|██████████| 647/647 [00:00<00:00, 173833.49it/s]
# Drawing 1382 posterior samples: 100%|██████████| 1382/1382 [00:00<00:00, 202216.23it/s]
# Drawing 618 posterior samples: 100%|██████████| 618/618 [00:00<00:00, 170173.31it/s]
# Drawing 1352 posterior samples: 100%|██████████| 1352/1352 [00:00<00:00, 208734.83it/s]
# Drawing 648 posterior samples: 100%|██████████| 648/648 [00:00<00:00, 175836.77it/s]
# Drawing 1370 posterior samples: 100%|██████████| 1370/1370 [00:00<00:00, 208618.81it/s]
# Drawing 630 posterior samples: 100%|██████████| 630/630 [00:00<00:00, 169276.84it/s]
# Drawing 1327 posterior samples: 100%|██████████| 1327/1327 [00:00<00:00, 201201.66it/s]
# Drawing 673 posterior samples: 100%|██████████| 673/673 [00:00<00:00, 180564.61it/s]
# Drawing 1357 posterior samples: 100%|██████████| 1357/1357 [00:00<00:00, 207233.59it/s]
# Drawing 643 posterior samples: 100%|██████████| 643/643 [00:00<00:00, 168970.46it/s]
# Drawing 1330 posterior samples: 100%|██████████| 1330/1330 [00:00<00:00, 204150.94it/s]
# Drawing 670 posterior samples: 100%|██████████| 670/670 [00:00<00:00, 178583.10it/s]
# Drawing 1318 posterior samples: 100%|██████████| 1318/1318 [00:00<00:00, 201615.40it/s]
# Drawing 682 posterior samples: 100%|██████████| 682/682 [00:00<00:00, 174730.64it/s]
# Drawing 1348 posterior samples: 100%|██████████| 1348/1348 [00:00<00:00, 205246.37it/s]
# Drawing 652 posterior samples: 100%|██████████| 652/652 [00:00<00:00, 174818.53it/s]
# Drawing 1330 posterior samples: 100%|██████████| 1330/1330 [00:00<00:00, 193594.46it/s]
# Drawing 670 posterior samples: 100%|██████████| 670/670 [00:00<00:00, 177972.37it/s]
# Drawing 1297 posterior samples: 100%|██████████| 1297/1297 [00:00<00:00, 193760.23it/s]
# Drawing 703 posterior samples: 100%|██████████| 703/703 [00:00<00:00, 166993.02it/s]
# Drawing 1333 posterior samples: 100%|██████████| 1333/1333 [00:00<00:00, 117406.34it/s]
# Drawing 667 posterior samples: 100%|██████████| 667/667 [00:00<00:00, 173033.20it/s]
# Drawing 1374 posterior samples: 100%|██████████| 1374/1374 [00:00<00:00, 200075.47it/s]
# Drawing 626 posterior samples: 100%|██████████| 626/626 [00:00<00:00, 163917.74it/s]
# Drawing 1324 posterior samples: 100%|██████████| 1324/1324 [00:00<00:00, 199578.02it/s]
# Drawing 676 posterior samples: 100%|██████████| 676/676 [00:00<00:00, 174935.19it/s]
# Drawing 1356 posterior samples: 100%|██████████| 1356/1356 [00:00<00:00, 205287.00it/s]
# Drawing 644 posterior samples: 100%|██████████| 644/644 [00:00<00:00, 83587.55it/s]
# Drawing 1319 posterior samples: 100%|██████████| 1319/1319 [00:00<00:00, 188680.02it/s]
# Drawing 681 posterior samples: 100%|██████████| 681/681 [00:00<00:00, 139728.06it/s]
# Drawing 1401 posterior samples: 100%|██████████| 1401/1401 [00:00<00:00, 196240.31it/s]
# Drawing 599 posterior samples: 100%|██████████| 599/599 [00:00<00:00, 160669.44it/s]
# Drawing 1349 posterior samples: 100%|██████████| 1349/1349 [00:00<00:00, 203624.58it/s]
# Drawing 651 posterior samples: 100%|██████████| 651/651 [00:00<00:00, 172162.16it/s]
# Drawing 1325 posterior samples: 100%|██████████| 1325/1325 [00:00<00:00, 199170.44it/s]
# Drawing 675 posterior samples: 100%|██████████| 675/675 [00:00<00:00, 176726.29it/s]
# Drawing 1373 posterior samples: 100%|██████████| 1373/1373 [00:00<00:00, 201814.59it/s]
# Drawing 627 posterior samples: 100%|██████████| 627/627 [00:00<00:00, 165606.34it/s]
# Drawing 1347 posterior samples: 100%|██████████| 1347/1347 [00:00<00:00, 43646.79it/s]
# Drawing 653 posterior samples: 100%|██████████| 653/653 [00:00<00:00, 168318.62it/s]
# Drawing 1355 posterior samples: 100%|██████████| 1355/1355 [00:01<00:00, 1102.49it/s]
# Drawing 645 posterior samples: 100%|██████████| 645/645 [00:00<00:00, 1146.23it/s]
# Drawing 1366 posterior samples: 100%|██████████| 1366/1366 [00:01<00:00, 1108.77it/s]
# Drawing 634 posterior samples: 100%|██████████| 634/634 [00:00<00:00, 1118.52it/s]
# Drawing 1395 posterior samples: 100%|██████████| 1395/1395 [00:01<00:00, 1134.89it/s]
# Drawing 605 posterior samples: 100%|██████████| 605/605 [00:00<00:00, 1067.35it/s]
# Drawing 1364 posterior samples: 100%|██████████| 1364/1364 [00:01<00:00, 1103.71it/s]
# Drawing 636 posterior samples: 100%|██████████| 636/636 [00:00<00:00, 1112.25it/s]
# Drawing 1300 posterior samples: 100%|██████████| 1300/1300 [00:01<00:00, 1054.12it/s]
# Drawing 700 posterior samples: 100%|██████████| 700/700 [00:00<00:00, 1207.92it/s]
# Drawing 1343 posterior samples: 100%|██████████| 1343/1343 [00:01<00:00, 1085.49it/s]
# Drawing 657 posterior samples: 100%|██████████| 657/657 [00:00<00:00, 1172.46it/s]
# Drawing 1360 posterior samples: 100%|██████████| 1360/1360 [00:01<00:00, 1095.44it/s]
# Drawing 640 posterior samples: 100%|██████████| 640/640 [00:00<00:00, 1124.83it/s]
# Drawing 1339 posterior samples: 100%|██████████| 1339/1339 [00:01<00:00, 1085.21it/s]
# Drawing 661 posterior samples: 100%|██████████| 661/661 [00:00<00:00, 1167.63it/s]
# Drawing 1280 posterior samples: 100%|██████████| 1280/1280 [00:01<00:00, 1036.85it/s]
# Drawing 720 posterior samples: 100%|██████████| 720/720 [00:00<00:00, 2332.60it/s]
# Drawing 1348 posterior samples: 100%|██████████| 1348/1348 [00:00<00:00, 203232.27it/s]
# Drawing 652 posterior samples: 100%|██████████| 652/652 [00:00<00:00, 165457.78it/s]
# Drawing 1335 posterior samples: 100%|██████████| 1335/1335 [00:00<00:00, 148655.21it/s]
# Drawing 665 posterior samples: 100%|██████████| 665/665 [00:00<00:00, 169217.51it/s]
# Drawing 1325 posterior samples: 100%|██████████| 1325/1325 [00:00<00:00, 198977.90it/s]
# Drawing 675 posterior samples: 100%|██████████| 675/675 [00:00<00:00, 176891.92it/s]
# Drawing 1347 posterior samples: 100%|██████████| 1347/1347 [00:00<00:00, 139227.86it/s]
# Drawing 653 posterior samples: 100%|██████████| 653/653 [00:00<00:00, 163730.30it/s]
# Drawing 1324 posterior samples: 100%|██████████| 1324/1324 [00:00<00:00, 185337.20it/s]
# Drawing 676 posterior samples: 100%|██████████| 676/676 [00:00<00:00, 29180.77it/s]
# Drawing 1311 posterior samples: 100%|██████████| 1311/1311 [00:00<00:00, 185229.82it/s]
# Drawing 689 posterior samples: 100%|██████████| 689/689 [00:00<00:00, 173827.10it/s]
# Drawing 1309 posterior samples: 100%|██████████| 1309/1309 [00:00<00:00, 188180.15it/s]
# Drawing 691 posterior samples: 100%|██████████| 691/691 [00:00<00:00, 89607.47it/s]
# Drawing 1369 posterior samples: 100%|██████████| 1369/1369 [00:00<00:00, 198444.87it/s]
# Drawing 631 posterior samples: 100%|██████████| 631/631 [00:00<00:00, 165361.19it/s]
# Drawing 1336 posterior samples: 100%|██████████| 1336/1336 [00:00<00:00, 189952.21it/s]
# Drawing 664 posterior samples: 100%|██████████| 664/664 [00:00<00:00, 172350.88it/s]
# Drawing 1351 posterior samples: 100%|██████████| 1351/1351 [00:00<00:00, 193819.42it/s]
# Drawing 649 posterior samples: 100%|██████████| 649/649 [00:00<00:00, 170729.01it/s]
# Drawing 1379 posterior samples: 100%|██████████| 1379/1379 [00:01<00:00, 1122.96it/s]
# Drawing 621 posterior samples: 100%|██████████| 621/621 [00:00<00:00, 1641.29it/s]
# Drawing 1346 posterior samples: 100%|██████████| 1346/1346 [00:00<00:00, 203244.89it/s]
# Drawing 654 posterior samples: 100%|██████████| 654/654 [00:00<00:00, 173865.43it/s]
# Drawing 1327 posterior samples: 100%|██████████| 1327/1327 [00:00<00:00, 196930.31it/s]
# Drawing 673 posterior samples: 100%|██████████| 673/673 [00:00<00:00, 175577.94it/s]
# Drawing 1358 posterior samples: 100%|██████████| 1358/1358 [00:00<00:00, 150955.82it/s]
# Drawing 642 posterior samples: 100%|██████████| 642/642 [00:00<00:00, 19148.26it/s]
# Drawing 1364 posterior samples: 100%|██████████| 1364/1364 [00:00<00:00, 206632.38it/s]
# Drawing 636 posterior samples: 100%|██████████| 636/636 [00:00<00:00, 167846.05it/s]
# Drawing 1379 posterior samples: 100%|██████████| 1379/1379 [00:00<00:00, 207883.59it/s]
# Drawing 621 posterior samples: 100%|██████████| 621/621 [00:00<00:00, 75420.96it/s]
# Drawing 1356 posterior samples: 100%|██████████| 1356/1356 [00:00<00:00, 208699.41it/s]
# Drawing 644 posterior samples: 100%|██████████| 644/644 [00:00<00:00, 170849.57it/s]
# Drawing 1324 posterior samples: 100%|██████████| 1324/1324 [00:00<00:00, 152365.31it/s]
# Drawing 676 posterior samples: 100%|██████████| 676/676 [00:00<00:00, 177921.03it/s]
# Drawing 1374 posterior samples: 100%|██████████| 1374/1374 [00:00<00:00, 136748.06it/s]
# Drawing 626 posterior samples: 100%|██████████| 626/626 [00:00<00:00, 165780.67it/s]
# Drawing 1359 posterior samples: 100%|██████████| 1359/1359 [00:00<00:00, 205897.24it/s]
# Drawing 641 posterior samples: 100%|██████████| 641/641 [00:00<00:00, 65505.66it/s]
# Drawing 1339 posterior samples: 100%|██████████| 1339/1339 [00:00<00:00, 197460.55it/s]
# Drawing 661 posterior samples: 100%|██████████| 661/661 [00:00<00:00, 172307.95it/s]
# Drawing 1377 posterior samples: 100%|██████████| 1377/1377 [00:00<00:00, 203328.87it/s]
# Drawing 623 posterior samples: 100%|██████████| 623/623 [00:00<00:00, 61332.04it/s]
# Drawing 1308 posterior samples: 100%|██████████| 1308/1308 [00:00<00:00, 192354.74it/s]
# Drawing 692 posterior samples: 100%|██████████| 692/692 [00:00<00:00, 174941.74it/s]
# Drawing 1325 posterior samples: 100%|██████████| 1325/1325 [00:00<00:00, 199700.05it/s]
# Drawing 675 posterior samples: 100%|██████████| 675/675 [00:00<00:00, 93215.96it/s]
# Drawing 1365 posterior samples: 100%|██████████| 1365/1365 [00:00<00:00, 206806.28it/s]
# Drawing 635 posterior samples: 100%|██████████| 635/635 [00:00<00:00, 169028.56it/s]
# Drawing 1354 posterior samples: 100%|██████████| 1354/1354 [00:00<00:00, 203027.59it/s]
# Drawing 646 posterior samples: 100%|██████████| 646/646 [00:00<00:00, 72309.80it/s]
# Drawing 1334 posterior samples: 100%|██████████| 1334/1334 [00:00<00:00, 197305.93it/s]
# Drawing 666 posterior samples: 100%|██████████| 666/666 [00:00<00:00, 170934.19it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:00<00:00, 200602.34it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 44625.33it/s]
# Drawing 1335 posterior samples: 100%|██████████| 1335/1335 [00:00<00:00, 200551.43it/s]
# Drawing 665 posterior samples: 100%|██████████| 665/665 [00:00<00:00, 171464.45it/s]
# Drawing 1315 posterior samples: 100%|██████████| 1315/1315 [00:00<00:00, 95953.62it/s]
# Drawing 685 posterior samples: 100%|██████████| 685/685 [00:00<00:00, 179187.87it/s]
# Drawing 1320 posterior samples: 100%|██████████| 1320/1320 [00:00<00:00, 192989.45it/s]
# Drawing 680 posterior samples: 100%|██████████| 680/680 [00:00<00:00, 91593.39it/s]
# Drawing 1337 posterior samples: 100%|██████████| 1337/1337 [00:00<00:00, 88612.99it/s]
# Drawing 663 posterior samples: 100%|██████████| 663/663 [00:00<00:00, 168647.19it/s]
# Drawing 1329 posterior samples: 100%|██████████| 1329/1329 [00:00<00:00, 133629.72it/s]
# Drawing 671 posterior samples: 100%|██████████| 671/671 [00:00<00:00, 108831.32it/s]
# Drawing 1363 posterior samples: 100%|██████████| 1363/1363 [00:00<00:00, 202991.03it/s]
# Drawing 637 posterior samples: 100%|██████████| 637/637 [00:00<00:00, 155371.69it/s]
# Drawing 1370 posterior samples: 100%|██████████| 1370/1370 [00:00<00:00, 136902.21it/s]
# Drawing 630 posterior samples: 100%|██████████| 630/630 [00:00<00:00, 165793.17it/s]
# Drawing 1330 posterior samples: 100%|██████████| 1330/1330 [00:00<00:00, 193823.16it/s]
# Drawing 670 posterior samples: 100%|██████████| 670/670 [00:00<00:00, 103988.44it/s]
# Drawing 1363 posterior samples: 100%|██████████| 1363/1363 [00:00<00:00, 158470.86it/s]
# Drawing 637 posterior samples: 100%|██████████| 637/637 [00:00<00:00, 165783.80it/s]
# Drawing 1340 posterior samples: 100%|██████████| 1340/1340 [00:00<00:00, 152627.83it/s]
# Drawing 660 posterior samples: 100%|██████████| 660/660 [00:00<00:00, 96451.02it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:00<00:00, 203342.78it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 148887.34it/s]
# Drawing 1338 posterior samples: 100%|██████████| 1338/1338 [00:00<00:00, 138611.87it/s]
# Drawing 662 posterior samples: 100%|██████████| 662/662 [00:00<00:00, 174072.42it/s]
# Drawing 1383 posterior samples: 100%|██████████| 1383/1383 [00:00<00:00, 206762.52it/s]
# Drawing 617 posterior samples: 100%|██████████| 617/617 [00:00<00:00, 161128.55it/s]
# Drawing 1353 posterior samples: 100%|██████████| 1353/1353 [00:00<00:00, 200087.91it/s]
# Drawing 647 posterior samples: 100%|██████████| 647/647 [00:00<00:00, 21370.19it/s]
# Drawing 1332 posterior samples: 100%|██████████| 1332/1332 [00:00<00:00, 203474.99it/s]
# Drawing 668 posterior samples: 100%|██████████| 668/668 [00:00<00:00, 18947.56it/s]
# Drawing 1320 posterior samples: 100%|██████████| 1320/1320 [00:00<00:00, 194317.05it/s]
# Drawing 680 posterior samples: 100%|██████████| 680/680 [00:00<00:00, 152961.85it/s]
# Drawing 1370 posterior samples: 100%|██████████| 1370/1370 [00:00<00:00, 130800.49it/s]
# Drawing 630 posterior samples: 100%|██████████| 630/630 [00:00<00:00, 89896.29it/s]
# Drawing 1327 posterior samples: 100%|██████████| 1327/1327 [00:00<00:00, 194480.64it/s]
# Drawing 673 posterior samples: 100%|██████████| 673/673 [00:00<00:00, 170931.73it/s]
# Drawing 1348 posterior samples: 100%|██████████| 1348/1348 [00:00<00:00, 194794.89it/s]
# Drawing 652 posterior samples: 100%|██████████| 652/652 [00:00<00:00, 161424.13it/s]
# Drawing 1369 posterior samples: 100%|██████████| 1369/1369 [00:00<00:00, 83233.10it/s]
# Drawing 631 posterior samples: 100%|██████████| 631/631 [00:00<00:00, 64248.92it/s]
# Drawing 1331 posterior samples: 100%|██████████| 1331/1331 [00:00<00:00, 204806.61it/s]
# Drawing 669 posterior samples: 100%|██████████| 669/669 [00:00<00:00, 178045.01it/s]
# Drawing 1326 posterior samples: 100%|██████████| 1326/1326 [00:00<00:00, 131381.63it/s]
# Drawing 674 posterior samples: 100%|██████████| 674/674 [00:00<00:00, 177874.59it/s]
# Drawing 1409 posterior samples: 100%|██████████| 1409/1409 [00:00<00:00, 204745.51it/s]
# Drawing 591 posterior samples: 100%|██████████| 591/591 [00:00<00:00, 157807.08it/s]
# Drawing 1333 posterior samples: 100%|██████████| 1333/1333 [00:00<00:00, 93353.05it/s]
# Drawing 667 posterior samples: 100%|██████████| 667/667 [00:00<00:00, 177478.96it/s]
# Drawing 1371 posterior samples: 100%|██████████| 1371/1371 [00:00<00:00, 174396.95it/s]
# Drawing 629 posterior samples: 100%|██████████| 629/629 [00:00<00:00, 85536.98it/s]
# Drawing 1331 posterior samples: 100%|██████████| 1331/1331 [00:00<00:00, 148245.22it/s]
# Drawing 669 posterior samples: 100%|██████████| 669/669 [00:00<00:00, 174915.18it/s]
# Drawing 1388 posterior samples: 100%|██████████| 1388/1388 [00:00<00:00, 205524.75it/s]
# Drawing 612 posterior samples: 100%|██████████| 612/612 [00:00<00:00, 75426.48it/s]
# Drawing 1331 posterior samples: 100%|██████████| 1331/1331 [00:00<00:00, 143001.07it/s]
# Drawing 669 posterior samples: 100%|██████████| 669/669 [00:00<00:00, 175824.89it/s]
# Drawing 1350 posterior samples: 100%|██████████| 1350/1350 [00:00<00:00, 199926.22it/s]
# Drawing 650 posterior samples: 100%|██████████| 650/650 [00:00<00:00, 168988.88it/s]
# Drawing 1368 posterior samples: 100%|██████████| 1368/1368 [00:00<00:00, 95905.06it/s]
# Drawing 632 posterior samples: 100%|██████████| 632/632 [00:00<00:00, 172275.31it/s]
# Drawing 1363 posterior samples: 100%|██████████| 1363/1363 [00:00<00:00, 192732.67it/s]
# Drawing 637 posterior samples: 100%|██████████| 637/637 [00:00<00:00, 167320.37it/s]
# Drawing 1323 posterior samples: 100%|██████████| 1323/1323 [00:00<00:00, 64055.50it/s]
# Drawing 677 posterior samples: 100%|██████████| 677/677 [00:00<00:00, 72194.24it/s]
# Drawing 1336 posterior samples: 100%|██████████| 1336/1336 [00:00<00:00, 202793.51it/s]
# Drawing 664 posterior samples: 100%|██████████| 664/664 [00:00<00:00, 177412.27it/s]
# Drawing 1361 posterior samples: 100%|██████████| 1361/1361 [00:00<00:00, 165026.96it/s]
# Drawing 639 posterior samples: 100%|██████████| 639/639 [00:00<00:00, 176221.99it/s]
# Drawing 1364 posterior samples: 100%|██████████| 1364/1364 [00:00<00:00, 202765.57it/s]
# Drawing 636 posterior samples: 100%|██████████| 636/636 [00:00<00:00, 169391.50it/s]
# Drawing 1337 posterior samples: 100%|██████████| 1337/1337 [00:00<00:00, 204506.93it/s]
# Drawing 663 posterior samples: 100%|██████████| 663/663 [00:00<00:00, 76348.01it/s]
# Drawing 1326 posterior samples: 100%|██████████| 1326/1326 [00:00<00:00, 199342.19it/s]
# Drawing 674 posterior samples: 100%|██████████| 674/674 [00:00<00:00, 16564.48it/s]
# Drawing 1363 posterior samples: 100%|██████████| 1363/1363 [00:00<00:00, 173279.47it/s]
# Drawing 637 posterior samples: 100%|██████████| 637/637 [00:00<00:00, 141768.63it/s]
# Drawing 1347 posterior samples: 100%|██████████| 1347/1347 [00:00<00:00, 197315.25it/s]
# Drawing 653 posterior samples: 100%|██████████| 653/653 [00:00<00:00, 174495.45it/s]
# Drawing 1315 posterior samples: 100%|██████████| 1315/1315 [00:00<00:00, 175519.02it/s]
# Drawing 685 posterior samples: 100%|██████████| 685/685 [00:00<00:00, 180505.01it/s]
# Drawing 1343 posterior samples: 100%|██████████| 1343/1343 [00:00<00:00, 198553.06it/s]
# Drawing 657 posterior samples: 100%|██████████| 657/657 [00:00<00:00, 177041.94it/s]
# Drawing 1354 posterior samples: 100%|██████████| 1354/1354 [00:00<00:00, 201350.39it/s]
# Drawing 646 posterior samples: 100%|██████████| 646/646 [00:00<00:00, 168157.41it/s]
# Drawing 1342 posterior samples: 100%|██████████| 1342/1342 [00:00<00:00, 86751.06it/s]
# Drawing 658 posterior samples: 100%|██████████| 658/658 [00:00<00:00, 82253.51it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:00<00:00, 131656.26it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 93865.97it/s]
# Drawing 1336 posterior samples: 100%|██████████| 1336/1336 [00:00<00:00, 197748.18it/s]
# Drawing 664 posterior samples: 100%|██████████| 664/664 [00:00<00:00, 171978.38it/s]
# Drawing 1331 posterior samples: 100%|██████████| 1331/1331 [00:00<00:00, 96190.68it/s]
# Drawing 669 posterior samples: 100%|██████████| 669/669 [00:00<00:00, 157127.86it/s]
# Drawing 1337 posterior samples: 100%|██████████| 1337/1337 [00:00<00:00, 202016.80it/s]
# Drawing 663 posterior samples: 100%|██████████| 663/663 [00:00<00:00, 177269.30it/s]
# Drawing 1354 posterior samples: 100%|██████████| 1354/1354 [00:00<00:00, 95909.47it/s]
# Drawing 646 posterior samples: 100%|██████████| 646/646 [00:00<00:00, 173776.32it/s]
# Drawing 1340 posterior samples: 100%|██████████| 1340/1340 [00:00<00:00, 198382.24it/s]
# Drawing 660 posterior samples: 100%|██████████| 660/660 [00:00<00:00, 78565.08it/s]
# Drawing 1327 posterior samples: 100%|██████████| 1327/1327 [00:00<00:00, 120418.02it/s]
# Drawing 673 posterior samples: 100%|██████████| 673/673 [00:00<00:00, 178905.22it/s]
# Drawing 1335 posterior samples: 100%|██████████| 1335/1335 [00:00<00:00, 126303.11it/s]
# Drawing 665 posterior samples: 100%|██████████| 665/665 [00:00<00:00, 178933.29it/s]
# Drawing 1334 posterior samples: 100%|██████████| 1334/1334 [00:00<00:00, 100256.26it/s]
# Drawing 666 posterior samples: 100%|██████████| 666/666 [00:00<00:00, 175003.54it/s]
# Drawing 1352 posterior samples: 100%|██████████| 1352/1352 [00:00<00:00, 201854.52it/s]
# Drawing 648 posterior samples: 100%|██████████| 648/648 [00:00<00:00, 175371.60it/s]
# Drawing 1378 posterior samples: 100%|██████████| 1378/1378 [00:00<00:00, 88770.38it/s]
# Drawing 622 posterior samples: 100%|██████████| 622/622 [00:00<00:00, 149504.70it/s]
# Drawing 1307 posterior samples: 100%|██████████| 1307/1307 [00:00<00:00, 194079.00it/s]
# Drawing 693 posterior samples: 100%|██████████| 693/693 [00:00<00:00, 177755.18it/s]
# Drawing 1343 posterior samples: 100%|██████████| 1343/1343 [00:00<00:00, 78703.27it/s]
# Drawing 657 posterior samples: 100%|██████████| 657/657 [00:00<00:00, 90316.86it/s]
# Drawing 1352 posterior samples: 100%|██████████| 1352/1352 [00:00<00:00, 113194.38it/s]
# Drawing 648 posterior samples: 100%|██████████| 648/648 [00:00<00:00, 67602.95it/s]
# Drawing 1332 posterior samples: 100%|██████████| 1332/1332 [00:00<00:00, 201051.28it/s]
# Drawing 668 posterior samples: 100%|██████████| 668/668 [00:00<00:00, 176981.56it/s]
# Drawing 1343 posterior samples: 100%|██████████| 1343/1343 [00:00<00:00, 201205.54it/s]
# Drawing 657 posterior samples: 100%|██████████| 657/657 [00:00<00:00, 176644.73it/s]
# Drawing 1340 posterior samples: 100%|██████████| 1340/1340 [00:00<00:00, 199998.84it/s]
# Drawing 660 posterior samples: 100%|██████████| 660/660 [00:00<00:00, 178044.81it/s]
# Drawing 1335 posterior samples: 100%|██████████| 1335/1335 [00:00<00:00, 198342.10it/s]
# Drawing 665 posterior samples: 100%|██████████| 665/665 [00:00<00:00, 177036.63it/s]
# Drawing 1386 posterior samples: 100%|██████████| 1386/1386 [00:00<00:00, 207292.30it/s]
# Drawing 614 posterior samples: 100%|██████████| 614/614 [00:00<00:00, 166902.31it/s]
# ...
# Drawing 1436 posterior samples: 100%|██████████| 1436/1436 [00:00<00:00, 211437.92it/s]
# Drawing 564 posterior samples: 100%|██████████| 564/564 [00:00<00:00, 3649.08it/s]
# Drawing 1461 posterior samples: 100%|██████████| 1461/1461 [00:00<00:00, 189911.62it/s]
# Drawing 539 posterior samples: 100%|██████████| 539/539 [00:00<00:00, 153228.27it/s]
# Drawing 1433 posterior samples: 100%|██████████| 1433/1433 [00:00<00:00, 203605.61it/s]
# Drawing 567 posterior samples: 100%|██████████| 567/567 [00:00<00:00, 134177.97it/s]
# Drawing 1436 posterior samples: 100%|██████████| 1436/1436 [00:00<00:00, 206352.63it/s]
# Drawing 564 posterior samples: 100%|██████████| 564/564 [00:00<00:00, 98755.43it/s]
# Drawing 1421 posterior samples: 100%|██████████| 1421/1421 [00:00<00:00, 208344.32it/s]
# Drawing 579 posterior samples: 100%|██████████| 579/579 [00:00<00:00, 159591.38it/s]
# Drawing 1404 posterior samples: 100%|██████████| 1404/1404 [00:00<00:00, 207688.61it/s]
# Drawing 596 posterior samples: 100%|██████████| 596/596 [00:00<00:00, 162874.98it/s]
# Drawing 1430 posterior samples: 100%|██████████| 1430/1430 [00:00<00:00, 208490.50it/s]
# Drawing 570 posterior samples: 100%|██████████| 570/570 [00:00<00:00, 158727.48it/s]
# Drawing 1415 posterior samples: 100%|██████████| 1415/1415 [00:00<00:00, 208323.92it/s]
# Drawing 585 posterior samples: 100%|██████████| 585/585 [00:00<00:00, 23335.60it/s]
# Drawing 1423 posterior samples: 100%|██████████| 1423/1423 [00:00<00:00, 210871.06it/s]
# Drawing 577 posterior samples: 100%|██████████| 577/577 [00:00<00:00, 74641.87it/s]
# Drawing 1443 posterior samples: 100%|██████████| 1443/1443 [00:00<00:00, 213895.27it/s]
# Drawing 557 posterior samples: 100%|██████████| 557/557 [00:00<00:00, 156699.13it/s]
# Drawing 1440 posterior samples: 100%|██████████| 1440/1440 [00:00<00:00, 210930.98it/s]
# Drawing 560 posterior samples: 100%|██████████| 560/560 [00:00<00:00, 152977.09it/s]
# Drawing 1431 posterior samples: 100%|██████████| 1431/1431 [00:00<00:00, 6352.23it/s]
# Drawing 569 posterior samples: 100%|██████████| 569/569 [00:00<00:00, 148890.07it/s]
# Drawing 1419 posterior samples: 100%|██████████| 1419/1419 [00:00<00:00, 203310.70it/s]
# Drawing 581 posterior samples: 100%|██████████| 581/581 [00:00<00:00, 156150.88it/s]
# Drawing 1442 posterior samples: 100%|██████████| 1442/1442 [00:00<00:00, 184807.23it/s]
# Drawing 558 posterior samples: 100%|██████████| 558/558 [00:00<00:00, 8264.81it/s]
# Drawing 1426 posterior samples: 100%|██████████| 1426/1426 [00:00<00:00, 112788.80it/s]
# Drawing 574 posterior samples: 100%|██████████| 574/574 [00:00<00:00, 157953.71it/s]
# Drawing 1430 posterior samples: 100%|██████████| 1430/1430 [00:00<00:00, 181879.94it/s]
# Drawing 570 posterior samples: 100%|██████████| 570/570 [00:00<00:00, 156791.27it/s]
# Drawing 1471 posterior samples: 100%|██████████| 1471/1471 [00:00<00:00, 209061.44it/s]
# Drawing 529 posterior samples: 100%|██████████| 529/529 [00:00<00:00, 149604.67it/s]
# Drawing 1461 posterior samples: 100%|██████████| 1461/1461 [00:00<00:00, 209028.45it/s]
# Drawing 539 posterior samples: 100%|██████████| 539/539 [00:00<00:00, 152700.43it/s]
# Drawing 1410 posterior samples: 100%|██████████| 1410/1410 [00:00<00:00, 79478.14it/s]
# Drawing 590 posterior samples: 100%|██████████| 590/590 [00:00<00:00, 144496.05it/s]
# Drawing 1441 posterior samples: 100%|██████████| 1441/1441 [00:00<00:00, 205591.95it/s]
# Drawing 559 posterior samples: 100%|██████████| 559/559 [00:00<00:00, 151696.17it/s]
# Drawing 1400 posterior samples: 100%|██████████| 1400/1400 [00:00<00:00, 6586.63it/s]
# Drawing 600 posterior samples: 100%|██████████| 600/600 [00:00<00:00, 161329.73it/s]
# Drawing 1476 posterior samples: 100%|██████████| 1476/1476 [00:00<00:00, 214058.74it/s]
# Drawing 524 posterior samples: 100%|██████████| 524/524 [00:00<00:00, 148390.74it/s]
# Drawing 1426 posterior samples: 100%|██████████| 1426/1426 [00:00<00:00, 203722.11it/s]
# Drawing 574 posterior samples: 100%|██████████| 574/574 [00:00<00:00, 157995.18it/s]
# Drawing 1413 posterior samples: 100%|██████████| 1413/1413 [00:00<00:00, 207956.47it/s]
# Drawing 587 posterior samples: 100%|██████████| 587/587 [00:00<00:00, 159604.33it/s]
# Drawing 1419 posterior samples: 100%|██████████| 1419/1419 [00:00<00:00, 202212.39it/s]
# Drawing 581 posterior samples: 100%|██████████| 581/581 [00:00<00:00, 160925.22it/s]
# Drawing 1399 posterior samples: 100%|██████████| 1399/1399 [00:00<00:00, 205082.88it/s]
# Drawing 601 posterior samples: 100%|██████████| 601/601 [00:00<00:00, 163814.45it/s]
# Drawing 1470 posterior samples: 100%|██████████| 1470/1470 [00:00<00:00, 208580.07it/s]
# Drawing 530 posterior samples: 100%|██████████| 530/530 [00:00<00:00, 143807.81it/s]
# Drawing 1409 posterior samples: 100%|██████████| 1409/1409 [00:00<00:00, 200175.26it/s]
# Drawing 591 posterior samples: 100%|██████████| 591/591 [00:00<00:00, 160224.53it/s]
# Drawing 1429 posterior samples: 100%|██████████| 1429/1429 [00:00<00:00, 19377.96it/s]
# Drawing 571 posterior samples: 100%|██████████| 571/571 [00:00<00:00, 157241.65it/s]
# Drawing 1413 posterior samples: 100%|██████████| 1413/1413 [00:00<00:00, 182490.19it/s]
# Drawing 587 posterior samples: 100%|██████████| 587/587 [00:00<00:00, 156619.37it/s]
# Drawing 1392 posterior samples: 100%|██████████| 1392/1392 [00:00<00:00, 194908.07it/s]
# Drawing 608 posterior samples: 100%|██████████| 608/608 [00:00<00:00, 159943.35it/s]
# Drawing 1433 posterior samples: 100%|██████████| 1433/1433 [00:00<00:00, 202973.04it/s]
# Drawing 567 posterior samples: 100%|██████████| 567/567 [00:00<00:00, 158407.40it/s]
# Drawing 1417 posterior samples: 100%|██████████| 1417/1417 [00:00<00:00, 203294.98it/s]
# Drawing 583 posterior samples: 100%|██████████| 583/583 [00:00<00:00, 157627.75it/s]
# Drawing 1432 posterior samples: 100%|██████████| 1432/1432 [00:00<00:00, 207033.31it/s]
# Drawing 568 posterior samples: 100%|██████████| 568/568 [00:00<00:00, 156538.84it/s]
# Drawing 1472 posterior samples: 100%|██████████| 1472/1472 [00:00<00:00, 75348.92it/s]
# Drawing 528 posterior samples: 100%|██████████| 528/528 [00:00<00:00, 146827.06it/s]
# Drawing 1436 posterior samples: 100%|██████████| 1436/1436 [00:00<00:00, 206841.60it/s]
# Drawing 564 posterior samples: 100%|██████████| 564/564 [00:00<00:00, 150895.42it/s]
# Drawing 1425 posterior samples: 100%|██████████| 1425/1425 [00:00<00:00, 205468.84it/s]
# Drawing 575 posterior samples: 100%|██████████| 575/575 [00:00<00:00, 159021.81it/s]
# Drawing 1438 posterior samples: 100%|██████████| 1438/1438 [00:00<00:00, 208843.81it/s]
# Drawing 562 posterior samples: 100%|██████████| 562/562 [00:00<00:00, 157999.79it/s]
# Drawing 1411 posterior samples: 100%|██████████| 1411/1411 [00:00<00:00, 15649.68it/s]
# Drawing 589 posterior samples: 100%|██████████| 589/589 [00:00<00:00, 149325.74it/s]
# Drawing 1442 posterior samples: 100%|██████████| 1442/1442 [00:00<00:00, 12128.05it/s]
# Drawing 558 posterior samples: 100%|██████████| 558/558 [00:00<00:00, 123825.28it/s]
# Drawing 1444 posterior samples: 100%|██████████| 1444/1444 [00:00<00:00, 196406.10it/s]
# Drawing 556 posterior samples: 100%|██████████| 556/556 [00:00<00:00, 152032.92it/s]
# Drawing 1438 posterior samples: 100%|██████████| 1438/1438 [00:00<00:00, 197919.84it/s]
# Drawing 562 posterior samples: 100%|██████████| 562/562 [00:00<00:00, 141191.90it/s]
# Drawing 1428 posterior samples: 100%|██████████| 1428/1428 [00:00<00:00, 199882.07it/s]
# Drawing 572 posterior samples: 100%|██████████| 572/572 [00:00<00:00, 134368.07it/s]
# Drawing 1442 posterior samples: 100%|██████████| 1442/1442 [00:00<00:00, 205608.73it/s]
# Drawing 558 posterior samples: 100%|██████████| 558/558 [00:00<00:00, 144114.63it/s]
# Drawing 1415 posterior samples: 100%|██████████| 1415/1415 [00:00<00:00, 194518.05it/s]
# Drawing 585 posterior samples: 100%|██████████| 585/585 [00:00<00:00, 152534.37it/s]
# Drawing 1413 posterior samples: 100%|██████████| 1413/1413 [00:00<00:00, 35961.65it/s]
# Drawing 587 posterior samples: 100%|██████████| 587/587 [00:00<00:00, 141367.50it/s]
# Drawing 1421 posterior samples: 100%|██████████| 1421/1421 [00:00<00:00, 196198.10it/s]
# Drawing 579 posterior samples: 100%|██████████| 579/579 [00:00<00:00, 10031.98it/s]
# Drawing 1438 posterior samples: 100%|██████████| 1438/1438 [00:00<00:00, 115786.01it/s]
# Drawing 562 posterior samples: 100%|██████████| 562/562 [00:00<00:00, 152826.69it/s]
# Drawing 1456 posterior samples: 100%|██████████| 1456/1456 [00:00<00:00, 190175.22it/s]
# Drawing 544 posterior samples: 100%|██████████| 544/544 [00:00<00:00, 150289.91it/s]
# Drawing 1422 posterior samples: 100%|██████████| 1422/1422 [00:00<00:00, 209383.90it/s]
# Drawing 578 posterior samples: 100%|██████████| 578/578 [00:00<00:00, 157719.58it/s]
# Drawing 1456 posterior samples: 100%|██████████| 1456/1456 [00:00<00:00, 210314.65it/s]
# Drawing 544 posterior samples: 100%|██████████| 544/544 [00:00<00:00, 150131.69it/s]
# Drawing 1428 posterior samples: 100%|██████████| 1428/1428 [00:00<00:00, 206255.94it/s]
# Drawing 572 posterior samples: 100%|██████████| 572/572 [00:00<00:00, 43443.04it/s]
# Drawing 1454 posterior samples: 100%|██████████| 1454/1454 [00:00<00:00, 201331.02it/s]
# Drawing 546 posterior samples: 100%|██████████| 546/546 [00:00<00:00, 152418.63it/s]
# Drawing 1450 posterior samples: 100%|██████████| 1450/1450 [00:00<00:00, 212166.08it/s]
# Drawing 550 posterior samples: 100%|██████████| 550/550 [00:00<00:00, 155732.61it/s]
# Drawing 1457 posterior samples: 100%|██████████| 1457/1457 [00:00<00:00, 95004.99it/s]
# Drawing 543 posterior samples: 100%|██████████| 543/543 [00:00<00:00, 149452.53it/s]
# Drawing 1474 posterior samples: 100%|██████████| 1474/1474 [00:00<00:00, 71254.59it/s]
# Drawing 526 posterior samples: 100%|██████████| 526/526 [00:00<00:00, 149017.49it/s]
# Drawing 1453 posterior samples: 100%|██████████| 1453/1453 [00:00<00:00, 22210.44it/s]
# Drawing 547 posterior samples: 100%|██████████| 547/547 [00:00<00:00, 148632.05it/s]
# Drawing 1452 posterior samples: 100%|██████████| 1452/1452 [00:00<00:00, 13211.70it/s]
# Drawing 548 posterior samples: 100%|██████████| 548/548 [00:00<00:00, 149835.63it/s]
# Drawing 1426 posterior samples: 100%|██████████| 1426/1426 [00:00<00:00, 206929.06it/s]
# Drawing 574 posterior samples: 100%|██████████| 574/574 [00:00<00:00, 152442.89it/s]
# Drawing 1467 posterior samples: 100%|██████████| 1467/1467 [00:00<00:00, 206991.99it/s]
# Drawing 533 posterior samples: 100%|██████████| 533/533 [00:00<00:00, 151082.25it/s]
# Drawing 1401 posterior samples: 100%|██████████| 1401/1401 [00:00<00:00, 202008.32it/s]
# Drawing 599 posterior samples: 100%|██████████| 599/599 [00:00<00:00, 163099.72it/s]
# Drawing 1446 posterior samples: 100%|██████████| 1446/1446 [00:00<00:00, 210245.90it/s]
# Drawing 554 posterior samples: 100%|██████████| 554/554 [00:00<00:00, 154816.74it/s]
# Drawing 1448 posterior samples: 100%|██████████| 1448/1448 [00:00<00:00, 209599.40it/s]
# Drawing 552 posterior samples: 100%|██████████| 552/552 [00:00<00:00, 155417.59it/s]
# Drawing 1467 posterior samples: 100%|██████████| 1467/1467 [00:00<00:00, 209401.17it/s]
# Drawing 533 posterior samples: 100%|██████████| 533/533 [00:00<00:00, 150735.89it/s]
# Drawing 1446 posterior samples: 100%|██████████| 1446/1446 [00:00<00:00, 14998.55it/s]
# Drawing 554 posterior samples: 100%|██████████| 554/554 [00:00<00:00, 141487.21it/s]
# Drawing 1411 posterior samples: 100%|██████████| 1411/1411 [00:00<00:00, 167085.35it/s]
# Drawing 589 posterior samples: 100%|██████████| 589/589 [00:00<00:00, 161583.17it/s]
# Drawing 1446 posterior samples: 100%|██████████| 1446/1446 [00:00<00:00, 84802.13it/s]
# Drawing 554 posterior samples: 100%|██████████| 554/554 [00:00<00:00, 73886.11it/s]
# Drawing 1406 posterior samples: 100%|██████████| 1406/1406 [00:00<00:00, 205341.11it/s]
# Drawing 594 posterior samples: 100%|██████████| 594/594 [00:00<00:00, 163500.23it/s]
# Drawing 1440 posterior samples: 100%|██████████| 1440/1440 [00:00<00:00, 197851.01it/s]
# Drawing 560 posterior samples: 100%|██████████| 560/560 [00:00<00:00, 157374.22it/s]
# Drawing 1457 posterior samples: 100%|██████████| 1457/1457 [00:00<00:00, 212132.08it/s]
# Drawing 543 posterior samples: 100%|██████████| 543/543 [00:00<00:00, 153295.22it/s]
# Drawing 1476 posterior samples: 100%|██████████| 1476/1476 [00:00<00:00, 7922.13it/s]
# Drawing 524 posterior samples: 100%|██████████| 524/524 [00:00<00:00, 129565.25it/s]
# Drawing 1478 posterior samples: 100%|██████████| 1478/1478 [00:00<00:00, 208621.28it/s]
# Drawing 522 posterior samples: 100%|██████████| 522/522 [00:00<00:00, 121056.44it/s]
# Drawing 1438 posterior samples: 100%|██████████| 1438/1438 [00:00<00:00, 200452.30it/s]
# Drawing 562 posterior samples: 100%|██████████| 562/562 [00:00<00:00, 152638.66it/s]
# Drawing 1460 posterior samples: 100%|██████████| 1460/1460 [00:00<00:00, 197870.10it/s]
# Drawing 540 posterior samples: 100%|██████████| 540/540 [00:00<00:00, 150124.22it/s]
# Drawing 1443 posterior samples: 100%|██████████| 1443/1443 [00:00<00:00, 205228.06it/s]
# Drawing 557 posterior samples: 100%|██████████| 557/557 [00:00<00:00, 155458.30it/s]
# Drawing 1380 posterior samples: 100%|██████████| 1380/1380 [00:00<00:00, 203092.61it/s]
# Drawing 620 posterior samples: 100%|██████████| 620/620 [00:00<00:00, 19760.85it/s]
# Drawing 1441 posterior samples: 100%|██████████| 1441/1441 [00:00<00:00, 32895.34it/s]
# Drawing 559 posterior samples: 100%|██████████| 559/559 [00:00<00:00, 156778.06it/s]
# Drawing 1467 posterior samples: 100%|██████████| 1467/1467 [00:00<00:00, 191994.63it/s]
# Drawing 533 posterior samples: 100%|██████████| 533/533 [00:00<00:00, 149716.32it/s]
# Drawing 1407 posterior samples: 100%|██████████| 1407/1407 [00:00<00:00, 212005.52it/s]
# Drawing 593 posterior samples: 100%|██████████| 593/593 [00:00<00:00, 50355.76it/s]
# Drawing 1445 posterior samples: 100%|██████████| 1445/1445 [00:00<00:00, 210604.26it/s]
# Drawing 555 posterior samples: 100%|██████████| 555/555 [00:00<00:00, 152755.35it/s]
# Drawing 1412 posterior samples: 100%|██████████| 1412/1412 [00:00<00:00, 199809.62it/s]
# Drawing 588 posterior samples: 100%|██████████| 588/588 [00:00<00:00, 158438.31it/s]
# Drawing 1433 posterior samples: 100%|██████████| 1433/1433 [00:00<00:00, 205879.21it/s]
# Drawing 567 posterior samples: 100%|██████████| 567/567 [00:00<00:00, 157557.33it/s]
# Drawing 1469 posterior samples: 100%|██████████| 1469/1469 [00:00<00:00, 209915.26it/s]
# Drawing 531 posterior samples: 100%|██████████| 531/531 [00:00<00:00, 15868.95it/s]
# Drawing 1436 posterior samples: 100%|██████████| 1436/1436 [00:00<00:00, 105604.04it/s]
# Drawing 564 posterior samples: 100%|██████████| 564/564 [00:00<00:00, 15098.31it/s]
# Drawing 1425 posterior samples: 100%|██████████| 1425/1425 [00:00<00:00, 202263.39it/s]
# Drawing 575 posterior samples: 100%|██████████| 575/575 [00:00<00:00, 157136.10it/s]
# Drawing 1411 posterior samples: 100%|██████████| 1411/1411 [00:00<00:00, 203933.94it/s]
# Drawing 589 posterior samples: 100%|██████████| 589/589 [00:00<00:00, 50123.66it/s]
# Drawing 1450 posterior samples: 100%|██████████| 1450/1450 [00:00<00:00, 210812.88it/s]
# Drawing 550 posterior samples: 100%|██████████| 550/550 [00:00<00:00, 147970.96it/s]
# Drawing 1435 posterior samples: 100%|██████████| 1435/1435 [00:00<00:00, 200634.23it/s]
# Drawing 565 posterior samples: 100%|██████████| 565/565 [00:00<00:00, 152997.72it/s]
# Drawing 1470 posterior samples: 100%|██████████| 1470/1470 [00:00<00:00, 200775.89it/s]
# Drawing 530 posterior samples: 100%|██████████| 530/530 [00:00<00:00, 17882.85it/s]
# Drawing 1461 posterior samples: 100%|██████████| 1461/1461 [00:00<00:00, 113719.30it/s]
# Drawing 539 posterior samples: 100%|██████████| 539/539 [00:00<00:00, 6338.44it/s]
# Drawing 1421 posterior samples: 100%|██████████| 1421/1421 [00:00<00:00, 39470.38it/s]
# Drawing 579 posterior samples: 100%|██████████| 579/579 [00:00<00:00, 159235.59it/s]
# Drawing 1406 posterior samples: 100%|██████████| 1406/1406 [00:00<00:00, 204146.90it/s]
# Drawing 594 posterior samples: 100%|██████████| 594/594 [00:00<00:00, 60874.64it/s]
# TailedNormal_NPE: 100%|██████████| 400/400 [00:12<00:00, 32.49it/s]

# %%
rect_evaluator.plot_c2st_grid(c2st_grid=c2st_grid, n_points_per_dim=n_points_per_dim)
# Out:
# Saved plot: toy-2-dim-figures/heatmap.png

# %%
class CircleEvaluator:
    def __init__(self, simulator, param_ranges, task):
        self.simulator = simulator
        self.param_ranges = param_ranges
        self.task = task
        self.prior_center = np.array([(low + high) / 2 for low, high in param_ranges])
        self.max_radius = min([(high - low) / 2 for low, high in param_ranges])

    def create_test_points(self, n_radii=20, n_angles=30):
        """Create test points on concentric circles"""
        test_points = [self.prior_center.copy()]
        radii = [0.0]

        for radius in np.linspace(0.2 * self.max_radius, 0.9 * self.max_radius, n_radii):
            for angle in np.linspace(0, 2*np.pi, n_angles, endpoint=False):
                x = self.prior_center[0] + radius * np.cos(angle)
                y = self.prior_center[1] + radius * np.sin(angle)

                if (self.param_ranges[0][0] <= x <= self.param_ranges[0][1] and 
                    self.param_ranges[1][0] <= y <= self.param_ranges[1][1]):
                    test_points.append([x, y])
                    radii.append(radius)

        return np.array(test_points), np.array(radii)

    def evaluate_all(self, posterior_dict, test_points, n_samples=n_posterior_samples):
        """Evaluate all posteriors including reference"""
        observations = []
        results = {'test_points': test_points}

        # Generate observations and reference posteriors
        for theta in tqdm(test_points):
            x_obs = self.simulator(torch.tensor(theta, dtype=torch.float32))
            observations.append(x_obs)

        results['observations'] = observations

        # Reference posteriors
        ref_samples = []
        for x_obs in tqdm(observations, desc="Reference"):
            ref_post = self.task._get_reference_posterior(observation=x_obs.unsqueeze(0))
            ref_samples.append(ref_post.sample((n_samples,)).cpu().numpy())
        results['Reference'] = ref_samples

        # Learned posteriors
        for name, posterior in posterior_dict.items():
            samples = []
            for x_obs in tqdm(observations, desc=name):
                samples.append(posterior.sample((n_samples,), x_obs).cpu().numpy())
            results[name] = samples

        return results

    def c2st(self, X1, X2):
        """C2ST score"""
        from sklearn.model_selection import train_test_split
        from sklearn.linear_model import LogisticRegression
        from sklearn.metrics import hamming_loss

        X = np.vstack([X1, X2])
        y = np.concatenate([np.zeros(len(X1)), np.ones(len(X2))])
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
        return hamming_loss(y_test, LogisticRegression(max_iter=1000).fit(X_train, y_train).predict(X_test))

    def compute_c2st_by_radius(self, results, radii):
        """Compute C2ST organized by radius"""
        methods = ['Uniform_NPE', 'TailedNormal_NPE', 'Reference']
        unique_radii = np.unique(np.round(radii, 3))
        c2st_data = {}

        for radius in unique_radii:
            indices = np.where(np.abs(radii - radius) < 1e-3)[0]
            c2st_data[f'{radius:.3f}'] = {}

            for i, m1 in enumerate(methods):
                for m2 in methods[i+1:]:
                    c2st_vals = [self.c2st(results[m1][idx], results[m2][idx]) for idx in indices]
                    c2st_data[f'{radius:.3f}'][f"{m1}_vs_{m2}"] = c2st_vals

        return c2st_data

    def plot_c2st_by_radius(self, c2st_data):
        """Plot average C2ST scores by radius"""
        comparisons = list(next(iter(c2st_data.values())).keys())
        radii = [float(r) for r in c2st_data.keys()]

        plt.figure(figsize=(10, 6))

        for comp in comparisons:
            avg_c2st = []
            for radius_str in c2st_data.keys():
                vals = c2st_data[radius_str][comp]
                avg_c2st.append(np.mean(vals))

            plt.plot(radii, avg_c2st, 'o-', label=comp)

        plt.axhline(0.5, color='gray', linestyle='--', linewidth=2, label='Ideal C2ST=0.5')
        plt.xlabel('Radius')
        plt.ylabel('Average Error Metric [C2ST]')
        plt.title('C2ST Performance by Distance from Center')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        filename = f'toy-2-dim-figures/c2st-radius.png'
        plt.savefig(filename, bbox_inches='tight')
        print(f"Saved plot: {filename}")
        plt.show()

    def plot_c2st_tables(self, c2st_data):
        """Plot C2ST as colored tables"""
        sns.set(style="white")
        comparisons = list(next(iter(c2st_data.values())).keys())
        fig, axes = plt.subplots(len(comparisons), 1, figsize=(20, 10*len(comparisons)))
        if len(comparisons) == 1: axes = [axes]

        for i, comp in enumerate(comparisons):
            radii = list(c2st_data.keys())
            max_pts = max(len(c2st_data[r][comp]) for r in radii)

            # Create data matrix
            data = np.full((len(radii), max_pts), np.nan)
            for j, r in enumerate(radii):
                vals = c2st_data[r][comp]
                data[j, :len(vals)] = vals

            # Plot
            im = axes[i].imshow(data, cmap='RdYlBu_r', vmin=0.3, vmax=0.6)

            # Add text
            for j in range(len(radii)):
                for k in range(max_pts):
                    if not np.isnan(data[j, k]):
                        color = 'white' if data[j, k] > 0.5 else 'black'
                        axes[i].text(k, j, f'{data[j, k]:.2f}', ha='center', va='center', 
                                     color=color, fontweight='bold')

            axes[i].set_yticks(range(len(radii)))
            axes[i].set_yticklabels([f'r={r}' for r in radii])
            axes[i].set_title(comp.replace('_', ' '))
            plt.colorbar(im, ax=axes[i])

        plt.tight_layout()
        plt.show()

# %%
evaluator = CircleEvaluator(simulator, param_ranges, task)
posterior_dict = {
    'Uniform_NPE': posterior_ensemble_old,
    'TailedNormal_NPE': posterior_ensemble
}

test_points, radii = evaluator.create_test_points()
results = evaluator.evaluate_all(posterior_dict, test_points)
c2st_data = evaluator.compute_c2st_by_radius(results, radii)
# Out:
# 100%|██████████| 601/601 [00:00<00:00, 6625.11it/s]
# Reference: 100%|██████████| 601/601 [00:00<00:00, 4316.66it/s]
# Drawing 1351 posterior samples: 100%|██████████| 1351/1351 [00:01<00:00, 1126.50it/s]
# Drawing 649 posterior samples: 100%|██████████| 649/649 [00:00<00:00, 1142.15it/s]
# Drawing 1351 posterior samples: 100%|██████████| 1351/1351 [00:01<00:00, 1094.78it/s]
# Drawing 649 posterior samples: 100%|██████████| 649/649 [00:00<00:00, 1138.56it/s]
# Drawing 1371 posterior samples: 100%|██████████| 1371/1371 [00:01<00:00, 1117.49it/s]
# Drawing 629 posterior samples: 100%|██████████| 629/629 [00:00<00:00, 2975.37it/s]
# Drawing 1374 posterior samples: 100%|██████████| 1374/1374 [00:00<00:00, 209806.82it/s]
# Drawing 626 posterior samples: 100%|██████████| 626/626 [00:00<00:00, 169823.06it/s]
# Drawing 1348 posterior samples: 100%|██████████| 1348/1348 [00:00<00:00, 205082.59it/s]
# Drawing 652 posterior samples: 100%|██████████| 652/652 [00:00<00:00, 175390.34it/s]
# Drawing 1338 posterior samples: 100%|██████████| 1338/1338 [00:00<00:00, 204816.74it/s]
# Drawing 662 posterior samples: 100%|██████████| 662/662 [00:00<00:00, 177920.62it/s]
# Drawing 1338 posterior samples: 100%|██████████| 1338/1338 [00:00<00:00, 160479.80it/s]
# Drawing 662 posterior samples: 100%|██████████| 662/662 [00:00<00:00, 177182.65it/s]
# Drawing 1332 posterior samples: 100%|██████████| 1332/1332 [00:00<00:00, 199422.20it/s]
# Drawing 668 posterior samples: 100%|██████████| 668/668 [00:00<00:00, 9209.31it/s]
# Drawing 1331 posterior samples: 100%|██████████| 1331/1331 [00:00<00:00, 206389.09it/s]
# Drawing 669 posterior samples: 100%|██████████| 669/669 [00:00<00:00, 176944.72it/s]
# Drawing 1386 posterior samples: 100%|██████████| 1386/1386 [00:00<00:00, 210094.16it/s]
# Drawing 614 posterior samples: 100%|██████████| 614/614 [00:00<00:00, 107708.18it/s]
# Drawing 1337 posterior samples: 100%|██████████| 1337/1337 [00:00<00:00, 173015.69it/s]
# Drawing 663 posterior samples: 100%|██████████| 663/663 [00:00<00:00, 177371.06it/s]
# Drawing 1337 posterior samples: 100%|██████████| 1337/1337 [00:00<00:00, 205278.00it/s]
# Drawing 663 posterior samples: 100%|██████████| 663/663 [00:00<00:00, 170948.76it/s]
# Drawing 1321 posterior samples: 100%|██████████| 1321/1321 [00:00<00:00, 199692.77it/s]
# Drawing 679 posterior samples: 100%|██████████| 679/679 [00:00<00:00, 58286.41it/s]
# Drawing 1346 posterior samples: 100%|██████████| 1346/1346 [00:00<00:00, 199785.31it/s]
# Drawing 654 posterior samples: 100%|██████████| 654/654 [00:00<00:00, 169116.82it/s]
# Drawing 1328 posterior samples: 100%|██████████| 1328/1328 [00:00<00:00, 207426.94it/s]
# Drawing 672 posterior samples: 100%|██████████| 672/672 [00:00<00:00, 77779.47it/s]
# Drawing 1368 posterior samples: 100%|██████████| 1368/1368 [00:01<00:00, 1116.53it/s]
# Drawing 632 posterior samples: 100%|██████████| 632/632 [00:00<00:00, 1185.63it/s]
# Drawing 1369 posterior samples: 100%|██████████| 1369/1369 [00:00<00:00, 208224.62it/s]
# Drawing 631 posterior samples: 100%|██████████| 631/631 [00:00<00:00, 155673.54it/s]
# Drawing 1354 posterior samples: 100%|██████████| 1354/1354 [00:00<00:00, 204851.12it/s]
# Drawing 646 posterior samples: 100%|██████████| 646/646 [00:00<00:00, 174301.73it/s]
# Drawing 1388 posterior samples: 100%|██████████| 1388/1388 [00:00<00:00, 205184.29it/s]
# Drawing 612 posterior samples: 100%|██████████| 612/612 [00:00<00:00, 170344.02it/s]
# Drawing 1339 posterior samples: 100%|██████████| 1339/1339 [00:00<00:00, 210162.52it/s]
# Drawing 661 posterior samples: 100%|██████████| 661/661 [00:00<00:00, 180567.60it/s]
# Drawing 1324 posterior samples: 100%|██████████| 1324/1324 [00:00<00:00, 200204.00it/s]
# Drawing 676 posterior samples: 100%|██████████| 676/676 [00:00<00:00, 180308.39it/s]
# Drawing 1341 posterior samples: 100%|██████████| 1341/1341 [00:00<00:00, 197755.49it/s]
# Drawing 659 posterior samples: 100%|██████████| 659/659 [00:00<00:00, 180256.05it/s]
# Drawing 1336 posterior samples: 100%|██████████| 1336/1336 [00:00<00:00, 200593.88it/s]
# Drawing 664 posterior samples: 100%|██████████| 664/664 [00:00<00:00, 181316.27it/s]
# Drawing 1322 posterior samples: 100%|██████████| 1322/1322 [00:00<00:00, 203930.49it/s]
# Drawing 678 posterior samples: 100%|██████████| 678/678 [00:00<00:00, 181673.68it/s]
# Drawing 1361 posterior samples: 100%|██████████| 1361/1361 [00:00<00:00, 210768.27it/s]
# Drawing 639 posterior samples: 100%|██████████| 639/639 [00:00<00:00, 175288.44it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:00<00:00, 209163.13it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 170648.43it/s]
# Drawing 1338 posterior samples: 100%|██████████| 1338/1338 [00:00<00:00, 183164.55it/s]
# Drawing 662 posterior samples: 100%|██████████| 662/662 [00:00<00:00, 178160.36it/s]
# Drawing 1340 posterior samples: 100%|██████████| 1340/1340 [00:00<00:00, 209809.14it/s]
# Drawing 660 posterior samples: 100%|██████████| 660/660 [00:00<00:00, 178665.33it/s]
# Drawing 1302 posterior samples: 100%|██████████| 1302/1302 [00:00<00:00, 200874.85it/s]
# Drawing 698 posterior samples: 100%|██████████| 698/698 [00:00<00:00, 177733.38it/s]
# Drawing 1335 posterior samples: 100%|██████████| 1335/1335 [00:00<00:00, 204186.12it/s]
# Drawing 665 posterior samples: 100%|██████████| 665/665 [00:00<00:00, 176264.67it/s]
# Drawing 1327 posterior samples: 100%|██████████| 1327/1327 [00:00<00:00, 205283.13it/s]
# Drawing 673 posterior samples: 100%|██████████| 673/673 [00:00<00:00, 176367.80it/s]
# Drawing 1330 posterior samples: 100%|██████████| 1330/1330 [00:00<00:00, 206493.59it/s]
# Drawing 670 posterior samples: 100%|██████████| 670/670 [00:00<00:00, 178040.02it/s]
# Drawing 1380 posterior samples: 100%|██████████| 1380/1380 [00:00<00:00, 214614.00it/s]
# Drawing 620 posterior samples: 100%|██████████| 620/620 [00:00<00:00, 168642.57it/s]
# Drawing 1352 posterior samples: 100%|██████████| 1352/1352 [00:00<00:00, 195527.86it/s]
# Drawing 648 posterior samples: 100%|██████████| 648/648 [00:00<00:00, 173148.31it/s]
# Drawing 1326 posterior samples: 100%|██████████| 1326/1326 [00:00<00:00, 182702.51it/s]
# Drawing 674 posterior samples: 100%|██████████| 674/674 [00:00<00:00, 175915.43it/s]
# Drawing 1389 posterior samples: 100%|██████████| 1389/1389 [00:00<00:00, 213269.69it/s]
# Drawing 611 posterior samples: 100%|██████████| 611/611 [00:00<00:00, 166086.83it/s]
# Drawing 1336 posterior samples: 100%|██████████| 1336/1336 [00:00<00:00, 202434.53it/s]
# Drawing 664 posterior samples: 100%|██████████| 664/664 [00:00<00:00, 174872.40it/s]
# Drawing 1306 posterior samples: 100%|██████████| 1306/1306 [00:00<00:00, 199612.31it/s]
# Drawing 694 posterior samples: 100%|██████████| 694/694 [00:00<00:00, 166191.66it/s]
# Drawing 1397 posterior samples: 100%|██████████| 1397/1397 [00:00<00:00, 211120.66it/s]
# Drawing 603 posterior samples: 100%|██████████| 603/603 [00:00<00:00, 166359.62it/s]
# Drawing 1317 posterior samples: 100%|██████████| 1317/1317 [00:00<00:00, 202726.75it/s]
# Drawing 683 posterior samples: 100%|██████████| 683/683 [00:00<00:00, 177216.80it/s]
# Drawing 1346 posterior samples: 100%|██████████| 1346/1346 [00:00<00:00, 202457.71it/s]
# Drawing 654 posterior samples: 100%|██████████| 654/654 [00:00<00:00, 120654.27it/s]
# Drawing 1346 posterior samples: 100%|██████████| 1346/1346 [00:00<00:00, 205823.51it/s]
# Drawing 654 posterior samples: 100%|██████████| 654/654 [00:00<00:00, 171807.27it/s]
# Drawing 1353 posterior samples: 100%|██████████| 1353/1353 [00:00<00:00, 214551.73it/s]
# Drawing 647 posterior samples: 100%|██████████| 647/647 [00:00<00:00, 175872.63it/s]
# Drawing 1350 posterior samples: 100%|██████████| 1350/1350 [00:00<00:00, 217764.42it/s]
# Drawing 650 posterior samples: 100%|██████████| 650/650 [00:00<00:00, 177782.69it/s]
# Drawing 1344 posterior samples: 100%|██████████| 1344/1344 [00:00<00:00, 212578.04it/s]
# Drawing 656 posterior samples: 100%|██████████| 656/656 [00:00<00:00, 178678.06it/s]
# Drawing 1327 posterior samples: 100%|██████████| 1327/1327 [00:00<00:00, 207386.59it/s]
# Drawing 673 posterior samples: 100%|██████████| 673/673 [00:00<00:00, 181388.42it/s]
# Drawing 1364 posterior samples: 100%|██████████| 1364/1364 [00:00<00:00, 213010.30it/s]
# Drawing 636 posterior samples: 100%|██████████| 636/636 [00:00<00:00, 173376.92it/s]
# Drawing 1361 posterior samples: 100%|██████████| 1361/1361 [00:00<00:00, 128224.98it/s]
# Drawing 639 posterior samples: 100%|██████████| 639/639 [00:00<00:00, 170569.61it/s]
# Drawing 1317 posterior samples: 100%|██████████| 1317/1317 [00:00<00:00, 197113.13it/s]
# Drawing 683 posterior samples: 100%|██████████| 683/683 [00:00<00:00, 183130.45it/s]
# Drawing 1344 posterior samples: 100%|██████████| 1344/1344 [00:00<00:00, 203059.85it/s]
# Drawing 656 posterior samples: 100%|██████████| 656/656 [00:00<00:00, 178736.09it/s]
# Drawing 1318 posterior samples: 100%|██████████| 1318/1318 [00:00<00:00, 199418.95it/s]
# Drawing 682 posterior samples: 100%|██████████| 682/682 [00:00<00:00, 182361.04it/s]
# Drawing 1372 posterior samples: 100%|██████████| 1372/1372 [00:00<00:00, 206791.18it/s]
# Drawing 628 posterior samples: 100%|██████████| 628/628 [00:00<00:00, 171452.38it/s]
# Drawing 1338 posterior samples: 100%|██████████| 1338/1338 [00:00<00:00, 201681.12it/s]
# Drawing 662 posterior samples: 100%|██████████| 662/662 [00:00<00:00, 172869.46it/s]
# Drawing 1328 posterior samples: 100%|██████████| 1328/1328 [00:00<00:00, 184407.74it/s]
# Drawing 672 posterior samples: 100%|██████████| 672/672 [00:00<00:00, 176072.73it/s]
# Drawing 1316 posterior samples: 100%|██████████| 1316/1316 [00:00<00:00, 193483.74it/s]
# Drawing 684 posterior samples: 100%|██████████| 684/684 [00:00<00:00, 178970.93it/s]
# Drawing 1315 posterior samples: 100%|██████████| 1315/1315 [00:00<00:00, 200040.25it/s]
# Drawing 685 posterior samples: 100%|██████████| 685/685 [00:00<00:00, 181485.58it/s]
# Drawing 1365 posterior samples: 100%|██████████| 1365/1365 [00:00<00:00, 199186.76it/s]
# Drawing 635 posterior samples: 100%|██████████| 635/635 [00:00<00:00, 167234.90it/s]
# Drawing 1354 posterior samples: 100%|██████████| 1354/1354 [00:00<00:00, 202354.81it/s]
# Drawing 646 posterior samples: 100%|██████████| 646/646 [00:00<00:00, 173609.30it/s]
# Drawing 1333 posterior samples: 100%|██████████| 1333/1333 [00:00<00:00, 199472.23it/s]
# Drawing 667 posterior samples: 100%|██████████| 667/667 [00:00<00:00, 176326.78it/s]
# Drawing 1351 posterior samples: 100%|██████████| 1351/1351 [00:00<00:00, 198115.68it/s]
# Drawing 649 posterior samples: 100%|██████████| 649/649 [00:00<00:00, 171947.65it/s]
# Drawing 1372 posterior samples: 100%|██████████| 1372/1372 [00:00<00:00, 204694.81it/s]
# Drawing 628 posterior samples: 100%|██████████| 628/628 [00:00<00:00, 169772.67it/s]
# Drawing 1370 posterior samples: 100%|██████████| 1370/1370 [00:00<00:00, 206334.03it/s]
# Drawing 630 posterior samples: 100%|██████████| 630/630 [00:00<00:00, 169135.99it/s]
# Drawing 1349 posterior samples: 100%|██████████| 1349/1349 [00:00<00:00, 197215.62it/s]
# Drawing 651 posterior samples: 100%|██████████| 651/651 [00:00<00:00, 152099.59it/s]
# Drawing 1330 posterior samples: 100%|██████████| 1330/1330 [00:00<00:00, 196409.56it/s]
# Drawing 670 posterior samples: 100%|██████████| 670/670 [00:00<00:00, 177175.69it/s]
# Drawing 1324 posterior samples: 100%|██████████| 1324/1324 [00:00<00:00, 197070.82it/s]
# Drawing 676 posterior samples: 100%|██████████| 676/676 [00:00<00:00, 174978.37it/s]
# Drawing 1329 posterior samples: 100%|██████████| 1329/1329 [00:00<00:00, 195237.65it/s]
# Drawing 671 posterior samples: 100%|██████████| 671/671 [00:00<00:00, 160748.11it/s]
# Drawing 1368 posterior samples: 100%|██████████| 1368/1368 [00:00<00:00, 203482.80it/s]
# Drawing 632 posterior samples: 100%|██████████| 632/632 [00:00<00:00, 166434.36it/s]
# Drawing 1378 posterior samples: 100%|██████████| 1378/1378 [00:00<00:00, 199632.18it/s]
# Drawing 622 posterior samples: 100%|██████████| 622/622 [00:00<00:00, 171601.47it/s]
# Drawing 1374 posterior samples: 100%|██████████| 1374/1374 [00:00<00:00, 198641.03it/s]
# Drawing 626 posterior samples: 100%|██████████| 626/626 [00:00<00:00, 169559.85it/s]
# Drawing 1359 posterior samples: 100%|██████████| 1359/1359 [00:00<00:00, 197699.05it/s]
# Drawing 641 posterior samples: 100%|██████████| 641/641 [00:00<00:00, 169635.24it/s]
# Drawing 1343 posterior samples: 100%|██████████| 1343/1343 [00:00<00:00, 190701.82it/s]
# Drawing 657 posterior samples: 100%|██████████| 657/657 [00:00<00:00, 173018.00it/s]
# Drawing 1374 posterior samples: 100%|██████████| 1374/1374 [00:00<00:00, 207952.00it/s]
# Drawing 626 posterior samples: 100%|██████████| 626/626 [00:00<00:00, 171442.00it/s]
# Drawing 1315 posterior samples: 100%|██████████| 1315/1315 [00:00<00:00, 200797.65it/s]
# Drawing 685 posterior samples: 100%|██████████| 685/685 [00:00<00:00, 178099.32it/s]
# Drawing 1373 posterior samples: 100%|██████████| 1373/1373 [00:00<00:00, 202602.71it/s]
# Drawing 627 posterior samples: 100%|██████████| 627/627 [00:00<00:00, 168179.87it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:00<00:00, 202394.39it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 172469.65it/s]
# Drawing 1326 posterior samples: 100%|██████████| 1326/1326 [00:00<00:00, 186432.26it/s]
# Drawing 674 posterior samples: 100%|██████████| 674/674 [00:00<00:00, 178514.83it/s]
# Drawing 1334 posterior samples: 100%|██████████| 1334/1334 [00:00<00:00, 196854.71it/s]
# Drawing 666 posterior samples: 100%|██████████| 666/666 [00:00<00:00, 180826.42it/s]
# Drawing 1350 posterior samples: 100%|██████████| 1350/1350 [00:00<00:00, 205007.62it/s]
# Drawing 650 posterior samples: 100%|██████████| 650/650 [00:00<00:00, 178949.63it/s]
# Drawing 1299 posterior samples: 100%|██████████| 1299/1299 [00:00<00:00, 200102.87it/s]
# Drawing 701 posterior samples: 100%|██████████| 701/701 [00:00<00:00, 2050.67it/s]
# Drawing 1356 posterior samples: 100%|██████████| 1356/1356 [00:00<00:00, 4084.06it/s]
# Drawing 644 posterior samples: 100%|██████████| 644/644 [00:00<00:00, 166223.49it/s]
# Drawing 1350 posterior samples: 100%|██████████| 1350/1350 [00:00<00:00, 201706.70it/s]
# Drawing 650 posterior samples: 100%|██████████| 650/650 [00:00<00:00, 179965.52it/s]
# Drawing 1326 posterior samples: 100%|██████████| 1326/1326 [00:00<00:00, 204818.70it/s]
# Drawing 674 posterior samples: 100%|██████████| 674/674 [00:00<00:00, 185630.11it/s]
# Drawing 1344 posterior samples: 100%|██████████| 1344/1344 [00:00<00:00, 208097.18it/s]
# Drawing 656 posterior samples: 100%|██████████| 656/656 [00:00<00:00, 182809.34it/s]
# Drawing 1319 posterior samples: 100%|██████████| 1319/1319 [00:00<00:00, 204331.93it/s]
# Drawing 681 posterior samples: 100%|██████████| 681/681 [00:00<00:00, 187017.68it/s]
# Drawing 1347 posterior samples: 100%|██████████| 1347/1347 [00:00<00:00, 208646.41it/s]
# Drawing 653 posterior samples: 100%|██████████| 653/653 [00:00<00:00, 182640.74it/s]
# Drawing 1358 posterior samples: 100%|██████████| 1358/1358 [00:00<00:00, 209560.88it/s]
# Drawing 642 posterior samples: 100%|██████████| 642/642 [00:00<00:00, 179086.40it/s]
# Drawing 1362 posterior samples: 100%|██████████| 1362/1362 [00:00<00:00, 203637.47it/s]
# Drawing 638 posterior samples: 100%|██████████| 638/638 [00:00<00:00, 178290.76it/s]
# Drawing 1338 posterior samples: 100%|██████████| 1338/1338 [00:00<00:00, 197222.94it/s]
# Drawing 662 posterior samples: 100%|██████████| 662/662 [00:00<00:00, 182277.24it/s]
# Drawing 1326 posterior samples: 100%|██████████| 1326/1326 [00:00<00:00, 198057.30it/s]
# Drawing 674 posterior samples: 100%|██████████| 674/674 [00:00<00:00, 183604.66it/s]
# Drawing 1352 posterior samples: 100%|██████████| 1352/1352 [00:00<00:00, 206470.02it/s]
# Drawing 648 posterior samples: 100%|██████████| 648/648 [00:00<00:00, 180820.24it/s]
# Drawing 1355 posterior samples: 100%|██████████| 1355/1355 [00:00<00:00, 164494.41it/s]
# Drawing 645 posterior samples: 100%|██████████| 645/645 [00:00<00:00, 178829.06it/s]
# Drawing 1350 posterior samples: 100%|██████████| 1350/1350 [00:00<00:00, 81947.27it/s]
# Drawing 650 posterior samples: 100%|██████████| 650/650 [00:00<00:00, 2444.10it/s]
# Drawing 1353 posterior samples: 100%|██████████| 1353/1353 [00:00<00:00, 1954.65it/s]
# Drawing 647 posterior samples: 100%|██████████| 647/647 [00:00<00:00, 169607.17it/s]
# Drawing 1331 posterior samples: 100%|██████████| 1331/1331 [00:00<00:00, 197733.81it/s]
# Drawing 669 posterior samples: 100%|██████████| 669/669 [00:00<00:00, 5944.00it/s]
# Drawing 1359 posterior samples: 100%|██████████| 1359/1359 [00:00<00:00, 90487.18it/s]
# Drawing 641 posterior samples: 100%|██████████| 641/641 [00:00<00:00, 3693.17it/s]
# Drawing 1354 posterior samples: 100%|██████████| 1354/1354 [00:00<00:00, 197946.59it/s]
# Drawing 646 posterior samples: 100%|██████████| 646/646 [00:00<00:00, 177150.73it/s]
# Drawing 1367 posterior samples: 100%|██████████| 1367/1367 [00:00<00:00, 200883.38it/s]
# Drawing 633 posterior samples: 100%|██████████| 633/633 [00:00<00:00, 12344.51it/s]
# Drawing 1364 posterior samples: 100%|██████████| 1364/1364 [00:00<00:00, 90680.47it/s]
# Drawing 636 posterior samples: 100%|██████████| 636/636 [00:00<00:00, 174865.77it/s]
# Drawing 1368 posterior samples: 100%|██████████| 1368/1368 [00:00<00:00, 205156.17it/s]
# Drawing 632 posterior samples: 100%|██████████| 632/632 [00:00<00:00, 173368.22it/s]
# Drawing 1337 posterior samples: 100%|██████████| 1337/1337 [00:00<00:00, 197819.40it/s]
# Drawing 663 posterior samples: 100%|██████████| 663/663 [00:00<00:00, 179570.16it/s]
# Drawing 1341 posterior samples: 100%|██████████| 1341/1341 [00:00<00:00, 200297.77it/s]
# Drawing 659 posterior samples: 100%|██████████| 659/659 [00:00<00:00, 179483.53it/s]
# Drawing 1380 posterior samples: 100%|██████████| 1380/1380 [00:00<00:00, 210011.96it/s]
# Drawing 620 posterior samples: 100%|██████████| 620/620 [00:00<00:00, 171151.01it/s]
# Drawing 1364 posterior samples: 100%|██████████| 1364/1364 [00:00<00:00, 208204.04it/s]
# Drawing 636 posterior samples: 100%|██████████| 636/636 [00:00<00:00, 175337.01it/s]
# Drawing 1343 posterior samples: 100%|██████████| 1343/1343 [00:00<00:00, 147020.68it/s]
# Drawing 657 posterior samples: 100%|██████████| 657/657 [00:00<00:00, 93228.83it/s]
# Drawing 1337 posterior samples: 100%|██████████| 1337/1337 [00:00<00:00, 199707.42it/s]
# Drawing 663 posterior samples: 100%|██████████| 663/663 [00:00<00:00, 168934.06it/s]
# Drawing 1353 posterior samples: 100%|██████████| 1353/1353 [00:00<00:00, 197504.38it/s]
# Drawing 647 posterior samples: 100%|██████████| 647/647 [00:00<00:00, 166587.76it/s]
# Drawing 1354 posterior samples: 100%|██████████| 1354/1354 [00:00<00:00, 159118.20it/s]
# Drawing 646 posterior samples: 100%|██████████| 646/646 [00:00<00:00, 115707.41it/s]
# Drawing 1341 posterior samples: 100%|██████████| 1341/1341 [00:00<00:00, 199036.12it/s]
# Drawing 659 posterior samples: 100%|██████████| 659/659 [00:00<00:00, 173392.28it/s]
# Drawing 1347 posterior samples: 100%|██████████| 1347/1347 [00:00<00:00, 200950.65it/s]
# Drawing 653 posterior samples: 100%|██████████| 653/653 [00:00<00:00, 174495.45it/s]
# Drawing 1367 posterior samples: 100%|██████████| 1367/1367 [00:00<00:00, 198587.34it/s]
# Drawing 633 posterior samples: 100%|██████████| 633/633 [00:00<00:00, 166134.44it/s]
# Drawing 1350 posterior samples: 100%|██████████| 1350/1350 [00:00<00:00, 194567.74it/s]
# Drawing 650 posterior samples: 100%|██████████| 650/650 [00:00<00:00, 74288.06it/s]
# Drawing 1350 posterior samples: 100%|██████████| 1350/1350 [00:00<00:00, 195582.55it/s]
# Drawing 650 posterior samples: 100%|██████████| 650/650 [00:00<00:00, 167175.47it/s]
# Drawing 1307 posterior samples: 100%|██████████| 1307/1307 [00:00<00:00, 96700.57it/s]
# Drawing 693 posterior samples: 100%|██████████| 693/693 [00:00<00:00, 2889.49it/s]
# Drawing 1363 posterior samples: 100%|██████████| 1363/1363 [00:00<00:00, 150951.53it/s]
# Drawing 637 posterior samples: 100%|██████████| 637/637 [00:00<00:00, 173649.53it/s]
# Drawing 1351 posterior samples: 100%|██████████| 1351/1351 [00:00<00:00, 205598.66it/s]
# Drawing 649 posterior samples: 100%|██████████| 649/649 [00:00<00:00, 176737.00it/s]
# Drawing 1343 posterior samples: 100%|██████████| 1343/1343 [00:00<00:00, 201126.51it/s]
# Drawing 657 posterior samples: 100%|██████████| 657/657 [00:00<00:00, 179545.07it/s]
# Drawing 1360 posterior samples: 100%|██████████| 1360/1360 [00:00<00:00, 206018.98it/s]
# Drawing 640 posterior samples: 100%|██████████| 640/640 [00:00<00:00, 176150.31it/s]
# Drawing 1358 posterior samples: 100%|██████████| 1358/1358 [00:00<00:00, 159543.57it/s]
# Drawing 642 posterior samples: 100%|██████████| 642/642 [00:00<00:00, 177200.79it/s]
# Drawing 1340 posterior samples: 100%|██████████| 1340/1340 [00:00<00:00, 208023.07it/s]
# Drawing 660 posterior samples: 100%|██████████| 660/660 [00:00<00:00, 92549.25it/s]
# Drawing 1351 posterior samples: 100%|██████████| 1351/1351 [00:00<00:00, 210384.82it/s]
# Drawing 649 posterior samples: 100%|██████████| 649/649 [00:00<00:00, 117246.13it/s]
# Drawing 1294 posterior samples: 100%|██████████| 1294/1294 [00:00<00:00, 204046.37it/s]
# Drawing 706 posterior samples: 100%|██████████| 706/706 [00:00<00:00, 2125.58it/s]
# Drawing 1368 posterior samples: 100%|██████████| 1368/1368 [00:01<00:00, 1107.93it/s]
# Drawing 632 posterior samples: 100%|██████████| 632/632 [00:00<00:00, 1112.18it/s]
# Drawing 1318 posterior samples: 100%|██████████| 1318/1318 [00:01<00:00, 1064.55it/s]
# Drawing 682 posterior samples: 100%|██████████| 682/682 [00:00<00:00, 1205.79it/s]
# Drawing 1365 posterior samples: 100%|██████████| 1365/1365 [00:01<00:00, 1105.47it/s]
# Drawing 635 posterior samples: 100%|██████████| 635/635 [00:00<00:00, 1107.93it/s]
# Drawing 1369 posterior samples: 100%|██████████| 1369/1369 [00:01<00:00, 1124.81it/s]
# Drawing 631 posterior samples: 100%|██████████| 631/631 [00:00<00:00, 1116.89it/s]
# Drawing 1334 posterior samples: 100%|██████████| 1334/1334 [00:01<00:00, 1079.95it/s]
# Drawing 666 posterior samples: 100%|██████████| 666/666 [00:00<00:00, 2460.26it/s]
# Drawing 1352 posterior samples: 100%|██████████| 1352/1352 [00:00<00:00, 3854.68it/s]
# Drawing 648 posterior samples: 100%|██████████| 648/648 [00:00<00:00, 4493.41it/s]
# Drawing 1316 posterior samples: 100%|██████████| 1316/1316 [00:00<00:00, 205071.48it/s]
# Drawing 684 posterior samples: 100%|██████████| 684/684 [00:00<00:00, 2050.20it/s]
# Drawing 1315 posterior samples: 100%|██████████| 1315/1315 [00:00<00:00, 6435.68it/s]
# Drawing 685 posterior samples: 100%|██████████| 685/685 [00:00<00:00, 179366.85it/s]
# Drawing 1342 posterior samples: 100%|██████████| 1342/1342 [00:00<00:00, 205864.82it/s]
# Drawing 658 posterior samples: 100%|██████████| 658/658 [00:00<00:00, 178608.08it/s]
# Drawing 1354 posterior samples: 100%|██████████| 1354/1354 [00:00<00:00, 204467.60it/s]
# Drawing 646 posterior samples: 100%|██████████| 646/646 [00:00<00:00, 176746.27it/s]
# Drawing 1335 posterior samples: 100%|██████████| 1335/1335 [00:00<00:00, 200904.02it/s]
# Drawing 665 posterior samples: 100%|██████████| 665/665 [00:00<00:00, 179682.55it/s]
# Drawing 1334 posterior samples: 100%|██████████| 1334/1334 [00:00<00:00, 202761.43it/s]
# Drawing 666 posterior samples: 100%|██████████| 666/666 [00:00<00:00, 108233.81it/s]
# Drawing 1312 posterior samples: 100%|██████████| 1312/1312 [00:00<00:00, 204076.65it/s]
# Drawing 688 posterior samples: 100%|██████████| 688/688 [00:00<00:00, 183988.85it/s]
# Drawing 1346 posterior samples: 100%|██████████| 1346/1346 [00:00<00:00, 208191.66it/s]
# Drawing 654 posterior samples: 100%|██████████| 654/654 [00:00<00:00, 178993.46it/s]
# Drawing 1352 posterior samples: 100%|██████████| 1352/1352 [00:00<00:00, 113013.91it/s]
# Drawing 648 posterior samples: 100%|██████████| 648/648 [00:00<00:00, 177386.05it/s]
# Drawing 1363 posterior samples: 100%|██████████| 1363/1363 [00:00<00:00, 210883.34it/s]
# Drawing 637 posterior samples: 100%|██████████| 637/637 [00:00<00:00, 1946.95it/s]
# Drawing 1376 posterior samples: 100%|██████████| 1376/1376 [00:01<00:00, 1098.86it/s]
# Drawing 624 posterior samples: 100%|██████████| 624/624 [00:00<00:00, 1310.70it/s]
# Drawing 1361 posterior samples: 100%|██████████| 1361/1361 [00:01<00:00, 1115.90it/s]
# Drawing 639 posterior samples: 100%|██████████| 639/639 [00:00<00:00, 1124.20it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:01<00:00, 1088.88it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 1154.38it/s]
# Drawing 1306 posterior samples: 100%|██████████| 1306/1306 [00:01<00:00, 1057.15it/s]
# Drawing 694 posterior samples: 100%|██████████| 694/694 [00:00<00:00, 1228.46it/s]
# Drawing 1332 posterior samples: 100%|██████████| 1332/1332 [00:00<00:00, 3755.95it/s]
# Drawing 668 posterior samples: 100%|██████████| 668/668 [00:00<00:00, 172556.20it/s]
# Drawing 1368 posterior samples: 100%|██████████| 1368/1368 [00:01<00:00, 1109.39it/s]
# Drawing 632 posterior samples: 100%|██████████| 632/632 [00:00<00:00, 1115.91it/s]
# Drawing 1347 posterior samples: 100%|██████████| 1347/1347 [00:00<00:00, 3750.74it/s]
# Drawing 653 posterior samples: 100%|██████████| 653/653 [00:00<00:00, 171986.22it/s]
# Drawing 1329 posterior samples: 100%|██████████| 1329/1329 [00:00<00:00, 16309.84it/s]
# Drawing 671 posterior samples: 100%|██████████| 671/671 [00:00<00:00, 34358.56it/s]
# Drawing 1336 posterior samples: 100%|██████████| 1336/1336 [00:00<00:00, 201372.41it/s]
# Drawing 664 posterior samples: 100%|██████████| 664/664 [00:00<00:00, 178286.78it/s]
# Drawing 1347 posterior samples: 100%|██████████| 1347/1347 [00:00<00:00, 203630.47it/s]
# Drawing 653 posterior samples: 100%|██████████| 653/653 [00:00<00:00, 176895.98it/s]
# Drawing 1367 posterior samples: 100%|██████████| 1367/1367 [00:00<00:00, 205101.54it/s]
# Drawing 633 posterior samples: 100%|██████████| 633/633 [00:00<00:00, 173597.13it/s]
# Drawing 1361 posterior samples: 100%|██████████| 1361/1361 [00:00<00:00, 206932.78it/s]
# Drawing 639 posterior samples: 100%|██████████| 639/639 [00:00<00:00, 175002.30it/s]
# Drawing 1330 posterior samples: 100%|██████████| 1330/1330 [00:00<00:00, 200043.90it/s]
# Drawing 670 posterior samples: 100%|██████████| 670/670 [00:00<00:00, 179312.38it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:00<00:00, 164662.55it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 55371.74it/s]
# Drawing 1374 posterior samples: 100%|██████████| 1374/1374 [00:00<00:00, 210951.12it/s]
# Drawing 626 posterior samples: 100%|██████████| 626/626 [00:00<00:00, 154167.95it/s]
# Drawing 1334 posterior samples: 100%|██████████| 1334/1334 [00:00<00:00, 204862.39it/s]
# Drawing 666 posterior samples: 100%|██████████| 666/666 [00:00<00:00, 179582.54it/s]
# Drawing 1362 posterior samples: 100%|██████████| 1362/1362 [00:00<00:00, 123671.68it/s]
# Drawing 638 posterior samples: 100%|██████████| 638/638 [00:00<00:00, 113110.40it/s]
# Drawing 1358 posterior samples: 100%|██████████| 1358/1358 [00:00<00:00, 202808.08it/s]
# Drawing 642 posterior samples: 100%|██████████| 642/642 [00:00<00:00, 172434.89it/s]
# Drawing 1351 posterior samples: 100%|██████████| 1351/1351 [00:00<00:00, 204168.94it/s]
# Drawing 649 posterior samples: 100%|██████████| 649/649 [00:00<00:00, 175914.65it/s]
# Drawing 1355 posterior samples: 100%|██████████| 1355/1355 [00:00<00:00, 197336.18it/s]
# Drawing 645 posterior samples: 100%|██████████| 645/645 [00:00<00:00, 68470.20it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:00<00:00, 201692.49it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 170457.85it/s]
# Drawing 1352 posterior samples: 100%|██████████| 1352/1352 [00:00<00:00, 200074.06it/s]
# Drawing 648 posterior samples: 100%|██████████| 648/648 [00:00<00:00, 103776.59it/s]
# Drawing 1303 posterior samples: 100%|██████████| 1303/1303 [00:00<00:00, 118250.39it/s]
# Drawing 697 posterior samples: 100%|██████████| 697/697 [00:00<00:00, 2028.77it/s]
# Drawing 1361 posterior samples: 100%|██████████| 1361/1361 [00:00<00:00, 83401.97it/s]
# Drawing 639 posterior samples: 100%|██████████| 639/639 [00:00<00:00, 154244.95it/s]
# Drawing 1339 posterior samples: 100%|██████████| 1339/1339 [00:00<00:00, 208485.15it/s]
# Drawing 661 posterior samples: 100%|██████████| 661/661 [00:00<00:00, 178774.50it/s]
# Drawing 1360 posterior samples: 100%|██████████| 1360/1360 [00:00<00:00, 203650.60it/s]
# Drawing 640 posterior samples: 100%|██████████| 640/640 [00:00<00:00, 175516.84it/s]
# Drawing 1327 posterior samples: 100%|██████████| 1327/1327 [00:00<00:00, 153807.76it/s]
# Drawing 673 posterior samples: 100%|██████████| 673/673 [00:00<00:00, 181283.58it/s]
# Drawing 1348 posterior samples: 100%|██████████| 1348/1348 [00:00<00:00, 204933.92it/s]
# Drawing 652 posterior samples: 100%|██████████| 652/652 [00:00<00:00, 176169.95it/s]
# Drawing 1351 posterior samples: 100%|██████████| 1351/1351 [00:00<00:00, 203166.06it/s]
# Drawing 649 posterior samples: 100%|██████████| 649/649 [00:00<00:00, 173991.90it/s]
# Drawing 1331 posterior samples: 100%|██████████| 1331/1331 [00:00<00:00, 200828.07it/s]
# Drawing 669 posterior samples: 100%|██████████| 669/669 [00:00<00:00, 176788.65it/s]
# Drawing 1370 posterior samples: 100%|██████████| 1370/1370 [00:00<00:00, 202444.92it/s]
# Drawing 630 posterior samples: 100%|██████████| 630/630 [00:00<00:00, 170819.80it/s]
# Drawing 1355 posterior samples: 100%|██████████| 1355/1355 [00:00<00:00, 158813.00it/s]
# Drawing 645 posterior samples: 100%|██████████| 645/645 [00:00<00:00, 170199.82it/s]
# Drawing 1328 posterior samples: 100%|██████████| 1328/1328 [00:00<00:00, 113516.66it/s]
# Drawing 672 posterior samples: 100%|██████████| 672/672 [00:00<00:00, 55630.45it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:00<00:00, 203306.14it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 71431.85it/s]
# Drawing 1374 posterior samples: 100%|██████████| 1374/1374 [00:00<00:00, 151314.75it/s]
# Drawing 626 posterior samples: 100%|██████████| 626/626 [00:00<00:00, 171812.22it/s]
# Drawing 1333 posterior samples: 100%|██████████| 1333/1333 [00:00<00:00, 159292.49it/s]
# Drawing 667 posterior samples: 100%|██████████| 667/667 [00:00<00:00, 176182.43it/s]
# Drawing 1314 posterior samples: 100%|██████████| 1314/1314 [00:00<00:00, 195415.93it/s]
# Drawing 686 posterior samples: 100%|██████████| 686/686 [00:00<00:00, 177009.69it/s]
# Drawing 1373 posterior samples: 100%|██████████| 1373/1373 [00:00<00:00, 204016.70it/s]
# Drawing 627 posterior samples: 100%|██████████| 627/627 [00:00<00:00, 163383.98it/s]
# Drawing 1353 posterior samples: 100%|██████████| 1353/1353 [00:00<00:00, 20003.15it/s]
# Drawing 647 posterior samples: 100%|██████████| 647/647 [00:00<00:00, 168868.37it/s]
# Drawing 1333 posterior samples: 100%|██████████| 1333/1333 [00:00<00:00, 205272.51it/s]
# Drawing 667 posterior samples: 100%|██████████| 667/667 [00:00<00:00, 176805.96it/s]
# Drawing 1369 posterior samples: 100%|██████████| 1369/1369 [00:00<00:00, 207509.75it/s]
# Drawing 631 posterior samples: 100%|██████████| 631/631 [00:00<00:00, 165423.20it/s]
# Drawing 1338 posterior samples: 100%|██████████| 1338/1338 [00:00<00:00, 192844.88it/s]
# Drawing 662 posterior samples: 100%|██████████| 662/662 [00:00<00:00, 167589.89it/s]
# Drawing 1343 posterior samples: 100%|██████████| 1343/1343 [00:00<00:00, 198427.16it/s]
# Drawing 657 posterior samples: 100%|██████████| 657/657 [00:00<00:00, 174596.57it/s]
# Drawing 1375 posterior samples: 100%|██████████| 1375/1375 [00:00<00:00, 8634.27it/s]
# Drawing 625 posterior samples: 100%|██████████| 625/625 [00:00<00:00, 162842.59it/s]
# Drawing 1329 posterior samples: 100%|██████████| 1329/1329 [00:00<00:00, 194420.50it/s]
# Drawing 671 posterior samples: 100%|██████████| 671/671 [00:00<00:00, 171066.01it/s]
# Drawing 1333 posterior samples: 100%|██████████| 1333/1333 [00:00<00:00, 193026.32it/s]
# Drawing 667 posterior samples: 100%|██████████| 667/667 [00:00<00:00, 169674.96it/s]
# Drawing 1324 posterior samples: 100%|██████████| 1324/1324 [00:00<00:00, 192427.27it/s]
# Drawing 676 posterior samples: 100%|██████████| 676/676 [00:00<00:00, 179885.14it/s]
# Drawing 1390 posterior samples: 100%|██████████| 1390/1390 [00:00<00:00, 202370.18it/s]
# Drawing 610 posterior samples: 100%|██████████| 610/610 [00:00<00:00, 81825.68it/s]
# Drawing 1322 posterior samples: 100%|██████████| 1322/1322 [00:00<00:00, 195869.51it/s]
# Drawing 678 posterior samples: 100%|██████████| 678/678 [00:00<00:00, 171889.39it/s]
# Drawing 1343 posterior samples: 100%|██████████| 1343/1343 [00:00<00:00, 116788.65it/s]
# Drawing 657 posterior samples: 100%|██████████| 657/657 [00:00<00:00, 175878.08it/s]
# Drawing 1336 posterior samples: 100%|██████████| 1336/1336 [00:00<00:00, 124341.86it/s]
# Drawing 664 posterior samples: 100%|██████████| 664/664 [00:00<00:00, 114214.97it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:00<00:00, 203203.62it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 107567.31it/s]
# Drawing 1329 posterior samples: 100%|██████████| 1329/1329 [00:00<00:00, 204326.45it/s]
# Drawing 671 posterior samples: 100%|██████████| 671/671 [00:00<00:00, 179351.13it/s]
# Drawing 1374 posterior samples: 100%|██████████| 1374/1374 [00:00<00:00, 208478.59it/s]
# Drawing 626 posterior samples: 100%|██████████| 626/626 [00:00<00:00, 79518.89it/s]
# Drawing 1356 posterior samples: 100%|██████████| 1356/1356 [00:00<00:00, 135525.81it/s]
# Drawing 644 posterior samples: 100%|██████████| 644/644 [00:00<00:00, 172662.48it/s]
# Drawing 1365 posterior samples: 100%|██████████| 1365/1365 [00:00<00:00, 196096.21it/s]
# Drawing 635 posterior samples: 100%|██████████| 635/635 [00:00<00:00, 166878.64it/s]
# Drawing 1342 posterior samples: 100%|██████████| 1342/1342 [00:00<00:00, 111246.83it/s]
# Drawing 658 posterior samples: 100%|██████████| 658/658 [00:00<00:00, 176777.61it/s]
# Drawing 1324 posterior samples: 100%|██████████| 1324/1324 [00:00<00:00, 145479.89it/s]
# Drawing 676 posterior samples: 100%|██████████| 676/676 [00:00<00:00, 149362.56it/s]
# Drawing 1357 posterior samples: 100%|██████████| 1357/1357 [00:00<00:00, 199406.88it/s]
# Drawing 643 posterior samples: 100%|██████████| 643/643 [00:00<00:00, 173637.49it/s]
# Drawing 1321 posterior samples: 100%|██████████| 1321/1321 [00:00<00:00, 150386.11it/s]
# Drawing 679 posterior samples: 100%|██████████| 679/679 [00:00<00:00, 130143.60it/s]
# Drawing 1376 posterior samples: 100%|██████████| 1376/1376 [00:00<00:00, 205335.41it/s]
# Drawing 624 posterior samples: 100%|██████████| 624/624 [00:00<00:00, 169763.62it/s]
# Drawing 1390 posterior samples: 100%|██████████| 1390/1390 [00:00<00:00, 204170.29it/s]
# Drawing 610 posterior samples: 100%|██████████| 610/610 [00:00<00:00, 162538.94it/s]
# Drawing 1341 posterior samples: 100%|██████████| 1341/1341 [00:00<00:00, 201222.15it/s]
# Drawing 659 posterior samples: 100%|██████████| 659/659 [00:00<00:00, 175964.24it/s]
# Drawing 1345 posterior samples: 100%|██████████| 1345/1345 [00:00<00:00, 41681.79it/s]
# Drawing 655 posterior samples: 100%|██████████| 655/655 [00:00<00:00, 175074.50it/s]
# Drawing 1369 posterior samples: 100%|██████████| 1369/1369 [00:00<00:00, 86608.98it/s]
# Drawing 631 posterior samples: 100%|██████████| 631/631 [00:00<00:00, 168896.35it/s]
# Drawing 1353 posterior samples: 100%|██████████| 1353/1353 [00:00<00:00, 200010.34it/s]
# Drawing 647 posterior samples: 100%|██████████| 647/647 [00:00<00:00, 172782.04it/s]
# Drawing 1356 posterior samples: 100%|██████████| 1356/1356 [00:00<00:00, 195331.81it/s]
# Drawing 644 posterior samples: 100%|██████████| 644/644 [00:00<00:00, 174514.26it/s]
# Drawing 1333 posterior samples: 100%|██████████| 1333/1333 [00:00<00:00, 200783.14it/s]
# Drawing 667 posterior samples: 100%|██████████| 667/667 [00:00<00:00, 169366.80it/s]
# Drawing 1359 posterior samples: 100%|██████████| 1359/1359 [00:00<00:00, 196262.75it/s]
# Drawing 641 posterior samples: 100%|██████████| 641/641 [00:00<00:00, 171935.08it/s]
# Drawing 1341 posterior samples: 100%|██████████| 1341/1341 [00:00<00:00, 198222.44it/s]
# Drawing 659 posterior samples: 100%|██████████| 659/659 [00:00<00:00, 173915.96it/s]
# Drawing 1336 posterior samples: 100%|██████████| 1336/1336 [00:00<00:00, 198694.78it/s]
# Drawing 664 posterior samples: 100%|██████████| 664/664 [00:00<00:00, 172907.30it/s]
# Drawing 1360 posterior samples: 100%|██████████| 1360/1360 [00:00<00:00, 197837.67it/s]
# Drawing 640 posterior samples: 100%|██████████| 640/640 [00:00<00:00, 29165.40it/s]
# Drawing 1336 posterior samples: 100%|██████████| 1336/1336 [00:00<00:00, 198821.68it/s]
# Drawing 664 posterior samples: 100%|██████████| 664/664 [00:00<00:00, 97204.91it/s]
# Drawing 1331 posterior samples: 100%|██████████| 1331/1331 [00:00<00:00, 202819.93it/s]
# Drawing 669 posterior samples: 100%|██████████| 669/669 [00:00<00:00, 176133.91it/s]
# Drawing 1338 posterior samples: 100%|██████████| 1338/1338 [00:00<00:00, 105211.45it/s]
# Drawing 662 posterior samples: 100%|██████████| 662/662 [00:00<00:00, 174938.84it/s]
# Drawing 1358 posterior samples: 100%|██████████| 1358/1358 [00:00<00:00, 204813.55it/s]
# Drawing 642 posterior samples: 100%|██████████| 642/642 [00:00<00:00, 110807.92it/s]
# Drawing 1354 posterior samples: 100%|██████████| 1354/1354 [00:00<00:00, 203354.73it/s]
# Drawing 646 posterior samples: 100%|██████████| 646/646 [00:00<00:00, 175396.19it/s]
# Drawing 1290 posterior samples: 100%|██████████| 1290/1290 [00:00<00:00, 143415.91it/s]
# Drawing 710 posterior samples: 100%|██████████| 710/710 [00:00<00:00, 2139.28it/s]
# Drawing 1338 posterior samples: 100%|██████████| 1338/1338 [00:01<00:00, 1071.75it/s]
# Drawing 662 posterior samples: 100%|██████████| 662/662 [00:00<00:00, 1197.04it/s]
# Drawing 1352 posterior samples: 100%|██████████| 1352/1352 [00:01<00:00, 1107.51it/s]
# Drawing 648 posterior samples: 100%|██████████| 648/648 [00:00<00:00, 1140.80it/s]
# Drawing 1353 posterior samples: 100%|██████████| 1353/1353 [00:01<00:00, 1112.05it/s]
# Drawing 647 posterior samples: 100%|██████████| 647/647 [00:00<00:00, 2348.79it/s]
# Drawing 1357 posterior samples: 100%|██████████| 1357/1357 [00:00<00:00, 194700.19it/s]
# Drawing 643 posterior samples: 100%|██████████| 643/643 [00:00<00:00, 151199.05it/s]
# Drawing 1360 posterior samples: 100%|██████████| 1360/1360 [00:00<00:00, 190605.59it/s]
# Drawing 640 posterior samples: 100%|██████████| 640/640 [00:00<00:00, 148397.07it/s]
# Drawing 1367 posterior samples: 100%|██████████| 1367/1367 [00:00<00:00, 79054.88it/s]
# Drawing 633 posterior samples: 100%|██████████| 633/633 [00:00<00:00, 160151.67it/s]
# Drawing 1351 posterior samples: 100%|██████████| 1351/1351 [00:00<00:00, 185774.86it/s]
# Drawing 649 posterior samples: 100%|██████████| 649/649 [00:00<00:00, 171525.10it/s]
# Drawing 1327 posterior samples: 100%|██████████| 1327/1327 [00:00<00:00, 125280.60it/s]
# Drawing 673 posterior samples: 100%|██████████| 673/673 [00:00<00:00, 179611.01it/s]
# Drawing 1330 posterior samples: 100%|██████████| 1330/1330 [00:00<00:00, 118942.95it/s]
# Drawing 670 posterior samples: 100%|██████████| 670/670 [00:00<00:00, 174393.92it/s]
# Drawing 1326 posterior samples: 100%|██████████| 1326/1326 [00:00<00:00, 200897.53it/s]
# Drawing 674 posterior samples: 100%|██████████| 674/674 [00:00<00:00, 175467.75it/s]
# Drawing 1339 posterior samples: 100%|██████████| 1339/1339 [00:00<00:00, 202428.38it/s]
# Drawing 661 posterior samples: 100%|██████████| 661/661 [00:00<00:00, 175470.57it/s]
# Drawing 1339 posterior samples: 100%|██████████| 1339/1339 [00:00<00:00, 88916.96it/s]
# Drawing 661 posterior samples: 100%|██████████| 661/661 [00:00<00:00, 176038.79it/s]
# Drawing 1341 posterior samples: 100%|██████████| 1341/1341 [00:00<00:00, 122576.86it/s]
# Drawing 659 posterior samples: 100%|██████████| 659/659 [00:00<00:00, 47691.33it/s]
# Drawing 1364 posterior samples: 100%|██████████| 1364/1364 [00:00<00:00, 196944.15it/s]
# Drawing 636 posterior samples: 100%|██████████| 636/636 [00:00<00:00, 81612.23it/s]
# Drawing 1350 posterior samples: 100%|██████████| 1350/1350 [00:00<00:00, 200485.44it/s]
# Drawing 650 posterior samples: 100%|██████████| 650/650 [00:00<00:00, 166909.37it/s]
# Drawing 1342 posterior samples: 100%|██████████| 1342/1342 [00:00<00:00, 201790.92it/s]
# Drawing 658 posterior samples: 100%|██████████| 658/658 [00:00<00:00, 98033.96it/s]
# Drawing 1386 posterior samples: 100%|██████████| 1386/1386 [00:00<00:00, 125451.68it/s]
# Drawing 614 posterior samples: 100%|██████████| 614/614 [00:00<00:00, 167434.02it/s]
# Drawing 1352 posterior samples: 100%|██████████| 1352/1352 [00:00<00:00, 200074.06it/s]
# Drawing 648 posterior samples: 100%|██████████| 648/648 [00:00<00:00, 171769.51it/s]
# Drawing 1311 posterior samples: 100%|██████████| 1311/1311 [00:00<00:00, 196005.29it/s]
# Drawing 689 posterior samples: 100%|██████████| 689/689 [00:00<00:00, 181696.04it/s]
# Drawing 1358 posterior samples: 100%|██████████| 1358/1358 [00:00<00:00, 198199.76it/s]
# Drawing 642 posterior samples: 100%|██████████| 642/642 [00:00<00:00, 124158.21it/s]
# Drawing 1369 posterior samples: 100%|██████████| 1369/1369 [00:00<00:00, 202797.28it/s]
# Drawing 631 posterior samples: 100%|██████████| 631/631 [00:00<00:00, 65361.20it/s]
# Drawing 1371 posterior samples: 100%|██████████| 1371/1371 [00:00<00:00, 203258.66it/s]
# Drawing 629 posterior samples: 100%|██████████| 629/629 [00:00<00:00, 165925.61it/s]
# Drawing 1342 posterior samples: 100%|██████████| 1342/1342 [00:00<00:00, 85804.21it/s]
# Drawing 658 posterior samples: 100%|██████████| 658/658 [00:00<00:00, 63026.15it/s]
# Drawing 1320 posterior samples: 100%|██████████| 1320/1320 [00:00<00:00, 202002.38it/s]
# Drawing 680 posterior samples: 100%|██████████| 680/680 [00:00<00:00, 178861.58it/s]
# Drawing 1373 posterior samples: 100%|██████████| 1373/1373 [00:00<00:00, 135395.56it/s]
# Drawing 627 posterior samples: 100%|██████████| 627/627 [00:00<00:00, 167911.42it/s]
# Drawing 1362 posterior samples: 100%|██████████| 1362/1362 [00:00<00:00, 197416.53it/s]
# Drawing 638 posterior samples: 100%|██████████| 638/638 [00:00<00:00, 164290.64it/s]
# Drawing 1372 posterior samples: 100%|██████████| 1372/1372 [00:00<00:00, 199576.37it/s]
# Drawing 628 posterior samples: 100%|██████████| 628/628 [00:00<00:00, 166689.21it/s]
# Drawing 1313 posterior samples: 100%|██████████| 1313/1313 [00:00<00:00, 161537.05it/s]
# Drawing 687 posterior samples: 100%|██████████| 687/687 [00:00<00:00, 97314.65it/s]
# Drawing 1340 posterior samples: 100%|██████████| 1340/1340 [00:00<00:00, 197489.98it/s]
# Drawing 660 posterior samples: 100%|██████████| 660/660 [00:00<00:00, 173448.66it/s]
# Drawing 1364 posterior samples: 100%|██████████| 1364/1364 [00:00<00:00, 58819.01it/s]
# Drawing 636 posterior samples: 100%|██████████| 636/636 [00:00<00:00, 52567.24it/s]
# Drawing 1386 posterior samples: 100%|██████████| 1386/1386 [00:00<00:00, 199126.72it/s]
# Drawing 614 posterior samples: 100%|██████████| 614/614 [00:00<00:00, 145046.62it/s]
# Drawing 1309 posterior samples: 100%|██████████| 1309/1309 [00:00<00:00, 193267.53it/s]
# Drawing 691 posterior samples: 100%|██████████| 691/691 [00:00<00:00, 181288.80it/s]
# Drawing 1359 posterior samples: 100%|██████████| 1359/1359 [00:00<00:00, 93947.21it/s]
# Drawing 641 posterior samples: 100%|██████████| 641/641 [00:00<00:00, 170010.68it/s]
# Drawing 1372 posterior samples: 100%|██████████| 1372/1372 [00:00<00:00, 197081.58it/s]
# Drawing 628 posterior samples: 100%|██████████| 628/628 [00:00<00:00, 51213.70it/s]
# Drawing 1321 posterior samples: 100%|██████████| 1321/1321 [00:00<00:00, 186084.82it/s]
# Drawing 679 posterior samples: 100%|██████████| 679/679 [00:00<00:00, 179793.71it/s]
# Drawing 1354 posterior samples: 100%|██████████| 1354/1354 [00:00<00:00, 201793.97it/s]
# Drawing 646 posterior samples: 100%|██████████| 646/646 [00:00<00:00, 173520.36it/s]
# Drawing 1338 posterior samples: 100%|██████████| 1338/1338 [00:00<00:00, 88892.78it/s]
# Drawing 662 posterior samples: 100%|██████████| 662/662 [00:00<00:00, 177295.78it/s]
# Drawing 1323 posterior samples: 100%|██████████| 1323/1323 [00:00<00:00, 197426.41it/s]
# Drawing 677 posterior samples: 100%|██████████| 677/677 [00:00<00:00, 173523.82it/s]
# Drawing 1352 posterior samples: 100%|██████████| 1352/1352 [00:00<00:00, 196055.14it/s]
# Drawing 648 posterior samples: 100%|██████████| 648/648 [00:00<00:00, 53571.75it/s]
# Drawing 1354 posterior samples: 100%|██████████| 1354/1354 [00:00<00:00, 151912.25it/s]
# Drawing 646 posterior samples: 100%|██████████| 646/646 [00:00<00:00, 174740.13it/s]
# Drawing 1341 posterior samples: 100%|██████████| 1341/1341 [00:00<00:00, 199177.08it/s]
# Drawing 659 posterior samples: 100%|██████████| 659/659 [00:00<00:00, 173229.28it/s]
# Drawing 1360 posterior samples: 100%|██████████| 1360/1360 [00:00<00:00, 198078.11it/s]
# Drawing 640 posterior samples: 100%|██████████| 640/640 [00:00<00:00, 173834.64it/s]
# Drawing 1352 posterior samples: 100%|██████████| 1352/1352 [00:00<00:00, 196517.15it/s]
# Drawing 648 posterior samples: 100%|██████████| 648/648 [00:00<00:00, 174024.14it/s]
# Drawing 1359 posterior samples: 100%|██████████| 1359/1359 [00:00<00:00, 200656.85it/s]
# Drawing 641 posterior samples: 100%|██████████| 641/641 [00:00<00:00, 55493.50it/s]
# Drawing 1373 posterior samples: 100%|██████████| 1373/1373 [00:00<00:00, 201208.18it/s]
# Drawing 627 posterior samples: 100%|██████████| 627/627 [00:00<00:00, 171424.85it/s]
# Drawing 1350 posterior samples: 100%|██████████| 1350/1350 [00:00<00:00, 194895.89it/s]
# Drawing 650 posterior samples: 100%|██████████| 650/650 [00:00<00:00, 168591.78it/s]
# Drawing 1346 posterior samples: 100%|██████████| 1346/1346 [00:00<00:00, 195896.22it/s]
# Drawing 654 posterior samples: 100%|██████████| 654/654 [00:00<00:00, 169618.77it/s]
# Drawing 1385 posterior samples: 100%|██████████| 1385/1385 [00:00<00:00, 191536.52it/s]
# Drawing 615 posterior samples: 100%|██████████| 615/615 [00:00<00:00, 168165.91it/s]
# Drawing 1369 posterior samples: 100%|██████████| 1369/1369 [00:00<00:00, 201374.84it/s]
# Drawing 631 posterior samples: 100%|██████████| 631/631 [00:00<00:00, 94437.32it/s]
# Drawing 1361 posterior samples: 100%|██████████| 1361/1361 [00:00<00:00, 200352.65it/s]
# Drawing 639 posterior samples: 100%|██████████| 639/639 [00:00<00:00, 170678.23it/s]
# Drawing 1382 posterior samples: 100%|██████████| 1382/1382 [00:00<00:00, 44449.18it/s]
# Drawing 618 posterior samples: 100%|██████████| 618/618 [00:00<00:00, 164639.22it/s]
# Drawing 1318 posterior samples: 100%|██████████| 1318/1318 [00:00<00:00, 189655.99it/s]
# Drawing 682 posterior samples: 100%|██████████| 682/682 [00:00<00:00, 76615.47it/s]
# Drawing 1334 posterior samples: 100%|██████████| 1334/1334 [00:00<00:00, 93457.41it/s]
# Drawing 666 posterior samples: 100%|██████████| 666/666 [00:00<00:00, 171775.09it/s]
# Drawing 1364 posterior samples: 100%|██████████| 1364/1364 [00:00<00:00, 202135.13it/s]
# Drawing 636 posterior samples: 100%|██████████| 636/636 [00:00<00:00, 173151.85it/s]
# Drawing 1328 posterior samples: 100%|██████████| 1328/1328 [00:00<00:00, 181896.54it/s]
# Drawing 672 posterior samples: 100%|██████████| 672/672 [00:00<00:00, 170905.43it/s]
# Drawing 1356 posterior samples: 100%|██████████| 1356/1356 [00:00<00:00, 111305.26it/s]
# Drawing 644 posterior samples: 100%|██████████| 644/644 [00:00<00:00, 171478.66it/s]
# Drawing 1349 posterior samples: 100%|██████████| 1349/1349 [00:00<00:00, 199355.79it/s]
# Drawing 651 posterior samples: 100%|██████████| 651/651 [00:00<00:00, 175323.74it/s]
# Drawing 1339 posterior samples: 100%|██████████| 1339/1339 [00:00<00:00, 197134.79it/s]
# Drawing 661 posterior samples: 100%|██████████| 661/661 [00:00<00:00, 12002.45it/s]
# Drawing 1334 posterior samples: 100%|██████████| 1334/1334 [00:00<00:00, 200631.15it/s]
# Drawing 666 posterior samples: 100%|██████████| 666/666 [00:00<00:00, 169863.57it/s]
# Drawing 1312 posterior samples: 100%|██████████| 1312/1312 [00:00<00:00, 41965.11it/s]
# Drawing 688 posterior samples: 100%|██████████| 688/688 [00:00<00:00, 161112.23it/s]
# Drawing 1371 posterior samples: 100%|██████████| 1371/1371 [00:00<00:00, 187425.14it/s]
# Drawing 629 posterior samples: 100%|██████████| 629/629 [00:00<00:00, 162112.40it/s]
# Drawing 1373 posterior samples: 100%|██████████| 1373/1373 [00:00<00:00, 192350.43it/s]
# Drawing 627 posterior samples: 100%|██████████| 627/627 [00:00<00:00, 165387.62it/s]
# Drawing 1362 posterior samples: 100%|██████████| 1362/1362 [00:00<00:00, 112526.68it/s]
# ...
# Drawing 1435 posterior samples: 100%|██████████| 1435/1435 [00:00<00:00, 219689.24it/s]
# Drawing 565 posterior samples: 100%|██████████| 565/565 [00:00<00:00, 156659.07it/s]
# Drawing 1427 posterior samples: 100%|██████████| 1427/1427 [00:00<00:00, 196438.08it/s]
# Drawing 573 posterior samples: 100%|██████████| 573/573 [00:00<00:00, 166217.32it/s]
# Drawing 1434 posterior samples: 100%|██████████| 1434/1434 [00:00<00:00, 194534.96it/s]
# Drawing 566 posterior samples: 100%|██████████| 566/566 [00:00<00:00, 136915.40it/s]
# Drawing 1476 posterior samples: 100%|██████████| 1476/1476 [00:00<00:00, 189954.06it/s]
# Drawing 524 posterior samples: 100%|██████████| 524/524 [00:00<00:00, 156439.27it/s]
# Drawing 1426 posterior samples: 100%|██████████| 1426/1426 [00:00<00:00, 20232.04it/s]
# Drawing 574 posterior samples: 100%|██████████| 574/574 [00:00<00:00, 165375.09it/s]
# Drawing 1486 posterior samples: 100%|██████████| 1486/1486 [00:00<00:00, 216196.74it/s]
# Drawing 514 posterior samples: 100%|██████████| 514/514 [00:00<00:00, 153530.28it/s]
# Drawing 1446 posterior samples: 100%|██████████| 1446/1446 [00:00<00:00, 211131.50it/s]
# Drawing 554 posterior samples: 100%|██████████| 554/554 [00:00<00:00, 158979.50it/s]
# Drawing 1443 posterior samples: 100%|██████████| 1443/1443 [00:00<00:00, 215855.80it/s]
# Drawing 557 posterior samples: 100%|██████████| 557/557 [00:00<00:00, 157258.17it/s]
# Drawing 1434 posterior samples: 100%|██████████| 1434/1434 [00:00<00:00, 213557.45it/s]
# Drawing 566 posterior samples: 100%|██████████| 566/566 [00:00<00:00, 160057.72it/s]
# Drawing 1452 posterior samples: 100%|██████████| 1452/1452 [00:00<00:00, 218629.00it/s]
# Drawing 548 posterior samples: 100%|██████████| 548/548 [00:00<00:00, 151056.69it/s]
# Drawing 1447 posterior samples: 100%|██████████| 1447/1447 [00:00<00:00, 215815.30it/s]
# Drawing 553 posterior samples: 100%|██████████| 553/553 [00:00<00:00, 157016.66it/s]
# Drawing 1424 posterior samples: 100%|██████████| 1424/1424 [00:00<00:00, 213676.62it/s]
# Drawing 576 posterior samples: 100%|██████████| 576/576 [00:00<00:00, 161751.41it/s]
# Drawing 1476 posterior samples: 100%|██████████| 1476/1476 [00:00<00:00, 226495.18it/s]
# Drawing 524 posterior samples: 100%|██████████| 524/524 [00:00<00:00, 156986.81it/s]
# Drawing 1452 posterior samples: 100%|██████████| 1452/1452 [00:00<00:00, 223409.00it/s]
# Drawing 548 posterior samples: 100%|██████████| 548/548 [00:00<00:00, 160642.90it/s]
# Drawing 1415 posterior samples: 100%|██████████| 1415/1415 [00:00<00:00, 219041.90it/s]
# Drawing 585 posterior samples: 100%|██████████| 585/585 [00:00<00:00, 168266.89it/s]
# Drawing 1413 posterior samples: 100%|██████████| 1413/1413 [00:00<00:00, 220810.42it/s]
# Drawing 587 posterior samples: 100%|██████████| 587/587 [00:00<00:00, 169820.42it/s]
# Drawing 1396 posterior samples: 100%|██████████| 1396/1396 [00:00<00:00, 213788.83it/s]
# Drawing 604 posterior samples: 100%|██████████| 604/604 [00:00<00:00, 169421.50it/s]
# Drawing 1449 posterior samples: 100%|██████████| 1449/1449 [00:00<00:00, 217544.71it/s]
# Drawing 551 posterior samples: 100%|██████████| 551/551 [00:00<00:00, 159218.84it/s]
# Drawing 1412 posterior samples: 100%|██████████| 1412/1412 [00:00<00:00, 209056.35it/s]
# Drawing 588 posterior samples: 100%|██████████| 588/588 [00:00<00:00, 164548.36it/s]
# Drawing 1485 posterior samples: 100%|██████████| 1485/1485 [00:00<00:00, 219137.37it/s]
# Drawing 515 posterior samples: 100%|██████████| 515/515 [00:00<00:00, 149661.65it/s]
# Drawing 1433 posterior samples: 100%|██████████| 1433/1433 [00:00<00:00, 209678.62it/s]
# Drawing 567 posterior samples: 100%|██████████| 567/567 [00:00<00:00, 159160.11it/s]
# Drawing 1404 posterior samples: 100%|██████████| 1404/1404 [00:00<00:00, 210502.33it/s]
# Drawing 596 posterior samples: 100%|██████████| 596/596 [00:00<00:00, 164093.82it/s]
# Drawing 1411 posterior samples: 100%|██████████| 1411/1411 [00:00<00:00, 210341.30it/s]
# Drawing 589 posterior samples: 100%|██████████| 589/589 [00:00<00:00, 161720.68it/s]
# Drawing 1469 posterior samples: 100%|██████████| 1469/1469 [00:00<00:00, 215216.48it/s]
# Drawing 531 posterior samples: 100%|██████████| 531/531 [00:00<00:00, 151446.72it/s]
# Drawing 1422 posterior samples: 100%|██████████| 1422/1422 [00:00<00:00, 212381.17it/s]
# Drawing 578 posterior samples: 100%|██████████| 578/578 [00:00<00:00, 161040.77it/s]
# Drawing 1462 posterior samples: 100%|██████████| 1462/1462 [00:00<00:00, 215326.65it/s]
# Drawing 538 posterior samples: 100%|██████████| 538/538 [00:00<00:00, 155784.30it/s]
# Drawing 1443 posterior samples: 100%|██████████| 1443/1443 [00:00<00:00, 214243.56it/s]
# Drawing 557 posterior samples: 100%|██████████| 557/557 [00:00<00:00, 158120.29it/s]
# Drawing 1436 posterior samples: 100%|██████████| 1436/1436 [00:00<00:00, 217037.96it/s]
# Drawing 564 posterior samples: 100%|██████████| 564/564 [00:00<00:00, 165160.05it/s]
# Drawing 1441 posterior samples: 100%|██████████| 1441/1441 [00:00<00:00, 223702.42it/s]
# Drawing 559 posterior samples: 100%|██████████| 559/559 [00:00<00:00, 161497.17it/s]
# Drawing 1448 posterior samples: 100%|██████████| 1448/1448 [00:00<00:00, 218011.06it/s]
# Drawing 552 posterior samples: 100%|██████████| 552/552 [00:00<00:00, 159299.28it/s]
# Drawing 1424 posterior samples: 100%|██████████| 1424/1424 [00:00<00:00, 174395.26it/s]
# Drawing 576 posterior samples: 100%|██████████| 576/576 [00:00<00:00, 164270.01it/s]
# Drawing 1431 posterior samples: 100%|██████████| 1431/1431 [00:00<00:00, 210502.19it/s]
# Drawing 569 posterior samples: 100%|██████████| 569/569 [00:00<00:00, 163116.60it/s]
# Drawing 1426 posterior samples: 100%|██████████| 1426/1426 [00:00<00:00, 16938.67it/s]
# Drawing 574 posterior samples: 100%|██████████| 574/574 [00:00<00:00, 143407.82it/s]
# Drawing 1457 posterior samples: 100%|██████████| 1457/1457 [00:00<00:00, 200574.40it/s]
# Drawing 543 posterior samples: 100%|██████████| 543/543 [00:00<00:00, 152372.19it/s]
# Drawing 1470 posterior samples: 100%|██████████| 1470/1470 [00:00<00:00, 93091.36it/s]
# Drawing 530 posterior samples: 100%|██████████| 530/530 [00:00<00:00, 142289.00it/s]
# Drawing 1423 posterior samples: 100%|██████████| 1423/1423 [00:00<00:00, 196597.21it/s]
# Drawing 577 posterior samples: 100%|██████████| 577/577 [00:00<00:00, 162521.89it/s]
# Drawing 1455 posterior samples: 100%|██████████| 1455/1455 [00:00<00:00, 210431.10it/s]
# Drawing 545 posterior samples: 100%|██████████| 545/545 [00:00<00:00, 158621.59it/s]
# Drawing 1412 posterior samples: 100%|██████████| 1412/1412 [00:00<00:00, 205923.41it/s]
# Drawing 588 posterior samples: 100%|██████████| 588/588 [00:00<00:00, 168644.06it/s]
# Drawing 1414 posterior samples: 100%|██████████| 1414/1414 [00:00<00:00, 210541.58it/s]
# Drawing 586 posterior samples: 100%|██████████| 586/586 [00:00<00:00, 170011.91it/s]
# Drawing 1446 posterior samples: 100%|██████████| 1446/1446 [00:00<00:00, 215092.51it/s]
# Drawing 554 posterior samples: 100%|██████████| 554/554 [00:00<00:00, 162686.02it/s]
# Drawing 1427 posterior samples: 100%|██████████| 1427/1427 [00:00<00:00, 214957.33it/s]
# Drawing 573 posterior samples: 100%|██████████| 573/573 [00:00<00:00, 165291.35it/s]
# Drawing 1403 posterior samples: 100%|██████████| 1403/1403 [00:00<00:00, 214955.02it/s]
# Drawing 597 posterior samples: 100%|██████████| 597/597 [00:00<00:00, 169532.80it/s]
# Drawing 1423 posterior samples: 100%|██████████| 1423/1423 [00:00<00:00, 214385.58it/s]
# Drawing 577 posterior samples: 100%|██████████| 577/577 [00:00<00:00, 168484.64it/s]
# Drawing 1449 posterior samples: 100%|██████████| 1449/1449 [00:00<00:00, 222059.50it/s]
# Drawing 551 posterior samples: 100%|██████████| 551/551 [00:00<00:00, 155627.04it/s]
# Drawing 1458 posterior samples: 100%|██████████| 1458/1458 [00:00<00:00, 210378.95it/s]
# Drawing 542 posterior samples: 100%|██████████| 542/542 [00:00<00:00, 156219.95it/s]
# Drawing 1445 posterior samples: 100%|██████████| 1445/1445 [00:00<00:00, 212882.66it/s]
# Drawing 555 posterior samples: 100%|██████████| 555/555 [00:00<00:00, 162467.81it/s]
# Drawing 1472 posterior samples: 100%|██████████| 1472/1472 [00:00<00:00, 223065.81it/s]
# Drawing 528 posterior samples: 100%|██████████| 528/528 [00:00<00:00, 155628.43it/s]
# Drawing 1416 posterior samples: 100%|██████████| 1416/1416 [00:00<00:00, 214223.58it/s]
# Drawing 584 posterior samples: 100%|██████████| 584/584 [00:00<00:00, 167577.04it/s]
# Drawing 1418 posterior samples: 100%|██████████| 1418/1418 [00:00<00:00, 216360.11it/s]
# Drawing 582 posterior samples: 100%|██████████| 582/582 [00:00<00:00, 167289.26it/s]
# Drawing 1441 posterior samples: 100%|██████████| 1441/1441 [00:00<00:00, 209678.82it/s]
# Drawing 559 posterior samples: 100%|██████████| 559/559 [00:00<00:00, 161999.30it/s]
# Drawing 1436 posterior samples: 100%|██████████| 1436/1436 [00:00<00:00, 212519.69it/s]
# Drawing 564 posterior samples: 100%|██████████| 564/564 [00:00<00:00, 163054.00it/s]
# Drawing 1431 posterior samples: 100%|██████████| 1431/1431 [00:00<00:00, 217253.01it/s]
# Drawing 569 posterior samples: 100%|██████████| 569/569 [00:00<00:00, 165733.26it/s]
# Drawing 1430 posterior samples: 100%|██████████| 1430/1430 [00:00<00:00, 222290.96it/s]
# Drawing 570 posterior samples: 100%|██████████| 570/570 [00:00<00:00, 164765.90it/s]
# Drawing 1452 posterior samples: 100%|██████████| 1452/1452 [00:00<00:00, 214592.30it/s]
# Drawing 548 posterior samples: 100%|██████████| 548/548 [00:00<00:00, 161014.26it/s]
# Drawing 1425 posterior samples: 100%|██████████| 1425/1425 [00:00<00:00, 216154.32it/s]
# Drawing 575 posterior samples: 100%|██████████| 575/575 [00:00<00:00, 164960.66it/s]
# Drawing 1467 posterior samples: 100%|██████████| 1467/1467 [00:00<00:00, 222734.62it/s]
# Drawing 533 posterior samples: 100%|██████████| 533/533 [00:00<00:00, 153393.99it/s]
# Drawing 1412 posterior samples: 100%|██████████| 1412/1412 [00:00<00:00, 207699.98it/s]
# Drawing 588 posterior samples: 100%|██████████| 588/588 [00:00<00:00, 166931.82it/s]
# Drawing 1475 posterior samples: 100%|██████████| 1475/1475 [00:00<00:00, 223431.63it/s]
# Drawing 525 posterior samples: 100%|██████████| 525/525 [00:00<00:00, 157714.48it/s]
# Drawing 1444 posterior samples: 100%|██████████| 1444/1444 [00:00<00:00, 220063.04it/s]
# Drawing 556 posterior samples: 100%|██████████| 556/556 [00:00<00:00, 164703.23it/s]
# Drawing 1446 posterior samples: 100%|██████████| 1446/1446 [00:00<00:00, 218628.15it/s]
# Drawing 554 posterior samples: 100%|██████████| 554/554 [00:00<00:00, 162800.00it/s]
# Drawing 1480 posterior samples: 100%|██████████| 1480/1480 [00:00<00:00, 224773.51it/s]
# Drawing 520 posterior samples: 100%|██████████| 520/520 [00:00<00:00, 150116.19it/s]
# Drawing 1422 posterior samples: 100%|██████████| 1422/1422 [00:00<00:00, 212290.45it/s]
# Drawing 578 posterior samples: 100%|██████████| 578/578 [00:00<00:00, 161976.86it/s]
# Drawing 1440 posterior samples: 100%|██████████| 1440/1440 [00:00<00:00, 135245.59it/s]
# Drawing 560 posterior samples: 100%|██████████| 560/560 [00:00<00:00, 161452.45it/s]
# Drawing 1452 posterior samples: 100%|██████████| 1452/1452 [00:00<00:00, 214071.83it/s]
# Drawing 548 posterior samples: 100%|██████████| 548/548 [00:00<00:00, 158976.25it/s]
# Drawing 1447 posterior samples: 100%|██████████| 1447/1447 [00:00<00:00, 214404.84it/s]
# Drawing 553 posterior samples: 100%|██████████| 553/553 [00:00<00:00, 159291.95it/s]
# Drawing 1432 posterior samples: 100%|██████████| 1432/1432 [00:00<00:00, 217704.28it/s]
# Drawing 568 posterior samples: 100%|██████████| 568/568 [00:00<00:00, 163477.98it/s]
# Drawing 1458 posterior samples: 100%|██████████| 1458/1458 [00:00<00:00, 215927.94it/s]
# Drawing 542 posterior samples: 100%|██████████| 542/542 [00:00<00:00, 158066.53it/s]
# Drawing 1436 posterior samples: 100%|██████████| 1436/1436 [00:00<00:00, 215778.33it/s]
# Drawing 564 posterior samples: 100%|██████████| 564/564 [00:00<00:00, 163065.24it/s]
# Drawing 1471 posterior samples: 100%|██████████| 1471/1471 [00:00<00:00, 217837.84it/s]
# Drawing 529 posterior samples: 100%|██████████| 529/529 [00:00<00:00, 156043.80it/s]
# Drawing 1420 posterior samples: 100%|██████████| 1420/1420 [00:00<00:00, 2122.18it/s]
# Drawing 580 posterior samples: 100%|██████████| 580/580 [00:00<00:00, 150333.48it/s]
# Drawing 1441 posterior samples: 100%|██████████| 1441/1441 [00:00<00:00, 208932.25it/s]
# Drawing 559 posterior samples: 100%|██████████| 559/559 [00:00<00:00, 153383.22it/s]
# Drawing 1474 posterior samples: 100%|██████████| 1474/1474 [00:00<00:00, 219444.29it/s]
# Drawing 526 posterior samples: 100%|██████████| 526/526 [00:00<00:00, 149827.09it/s]
# Drawing 1388 posterior samples: 100%|██████████| 1388/1388 [00:00<00:00, 217300.36it/s]
# Drawing 612 posterior samples: 100%|██████████| 612/612 [00:00<00:00, 165682.18it/s]
# Drawing 1450 posterior samples: 100%|██████████| 1450/1450 [00:00<00:00, 220097.74it/s]
# Drawing 550 posterior samples: 100%|██████████| 550/550 [00:00<00:00, 157272.10it/s]
# Drawing 1436 posterior samples: 100%|██████████| 1436/1436 [00:00<00:00, 214502.67it/s]
# Drawing 564 posterior samples: 100%|██████████| 564/564 [00:00<00:00, 156082.57it/s]
# Drawing 1417 posterior samples: 100%|██████████| 1417/1417 [00:00<00:00, 213213.59it/s]
# Drawing 583 posterior samples: 100%|██████████| 583/583 [00:00<00:00, 160672.79it/s]
# Drawing 1462 posterior samples: 100%|██████████| 1462/1462 [00:00<00:00, 214340.68it/s]
# Drawing 538 posterior samples: 100%|██████████| 538/538 [00:00<00:00, 151161.28it/s]
# Drawing 1430 posterior samples: 100%|██████████| 1430/1430 [00:00<00:00, 213439.19it/s]
# Drawing 570 posterior samples: 100%|██████████| 570/570 [00:00<00:00, 163515.03it/s]
# Drawing 1433 posterior samples: 100%|██████████| 1433/1433 [00:00<00:00, 217391.41it/s]
# Drawing 567 posterior samples: 100%|██████████| 567/567 [00:00<00:00, 153618.65it/s]
# Drawing 1463 posterior samples: 100%|██████████| 1463/1463 [00:00<00:00, 225126.27it/s]
# Drawing 537 posterior samples: 100%|██████████| 537/537 [00:00<00:00, 156098.22it/s]
# Drawing 1402 posterior samples: 100%|██████████| 1402/1402 [00:00<00:00, 216605.80it/s]
# Drawing 598 posterior samples: 100%|██████████| 598/598 [00:00<00:00, 169885.79it/s]
# Drawing 1436 posterior samples: 100%|██████████| 1436/1436 [00:00<00:00, 221573.06it/s]
# Drawing 564 posterior samples: 100%|██████████| 564/564 [00:00<00:00, 158860.21it/s]
# Drawing 1425 posterior samples: 100%|██████████| 1425/1425 [00:00<00:00, 221046.75it/s]
# Drawing 575 posterior samples: 100%|██████████| 575/575 [00:00<00:00, 165799.86it/s]
# Drawing 1412 posterior samples: 100%|██████████| 1412/1412 [00:00<00:00, 216753.55it/s]
# Drawing 588 posterior samples: 100%|██████████| 588/588 [00:00<00:00, 165542.41it/s]
# Drawing 1444 posterior samples: 100%|██████████| 1444/1444 [00:00<00:00, 219012.62it/s]
# Drawing 556 posterior samples: 100%|██████████| 556/556 [00:00<00:00, 160907.54it/s]
# Drawing 1449 posterior samples: 100%|██████████| 1449/1449 [00:00<00:00, 218271.32it/s]
# Drawing 551 posterior samples: 100%|██████████| 551/551 [00:00<00:00, 158912.29it/s]
# Drawing 1415 posterior samples: 100%|██████████| 1415/1415 [00:00<00:00, 207073.73it/s]
# Drawing 585 posterior samples: 100%|██████████| 585/585 [00:00<00:00, 162247.43it/s]
# Drawing 1414 posterior samples: 100%|██████████| 1414/1414 [00:00<00:00, 213489.77it/s]
# Drawing 586 posterior samples: 100%|██████████| 586/586 [00:00<00:00, 155600.29it/s]
# Drawing 1427 posterior samples: 100%|██████████| 1427/1427 [00:00<00:00, 214004.28it/s]
# Drawing 573 posterior samples: 100%|██████████| 573/573 [00:00<00:00, 157513.19it/s]
# Drawing 1442 posterior samples: 100%|██████████| 1442/1442 [00:00<00:00, 215968.09it/s]
# Drawing 558 posterior samples: 100%|██████████| 558/558 [00:00<00:00, 156487.14it/s]
# Drawing 1411 posterior samples: 100%|██████████| 1411/1411 [00:00<00:00, 212310.78it/s]
# Drawing 589 posterior samples: 100%|██████████| 589/589 [00:00<00:00, 164291.09it/s]
# Drawing 1475 posterior samples: 100%|██████████| 1475/1475 [00:00<00:00, 218291.46it/s]
# Drawing 525 posterior samples: 100%|██████████| 525/525 [00:00<00:00, 152949.20it/s]
# TailedNormal_NPE: 100%|██████████| 601/601 [01:09<00:00,  8.65it/s]

# %%
evaluator.plot_c2st_by_radius(c2st_data)
# Out:
# Saved plot: toy-2-dim-figures/c2st-radius.png
